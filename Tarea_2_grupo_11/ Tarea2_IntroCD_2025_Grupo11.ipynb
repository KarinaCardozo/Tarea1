# %% [markdown]
# # Introducción a la Ciencia de Datos: Tarea 2
#
# Este notebook contiene el código de base para realizar la Tarea 2 del curso. Puede copiarlo en su propio repositorio y trabajar sobre el mismo.
# Las **instrucciones para ejecutar el notebook** están en la [página inicial del repositorio](https://gitlab.fing.edu.uy/maestria-cdaa/intro-cd/).
#
# **Se espera que no sea necesario revisar el código para corregir la tarea**, ya que todos los resultados y análisis relevantes deberían estar en el **informe en formato PDF**.

# %% [markdown]
# ## Cargar bibliotecas (dependencias)
# Recuerde instalar los requerimientos (requirements.txt) en el mismo entorno donde está ejecutando este notebook (ver [README](https://gitlab.fing.edu.uy/maestria-cdaa/intro-cd/)). Para la entrega 2 hay nuevas dependencias, por lo que es importante correr la siguiente celda.

# %%
#!pip install -r requirements.txt

# %%
import re
import os

from time import time
from pathlib import Path
from collections import Counter
import itertools
from itertools import chain
import unicodedata
import string

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from nltk.corpus import stopwords
import nltk
import matplotlib.patches as mpatches


from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.decomposition import PCA
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import cross_val_score

# %% [markdown]
# ## Lectura de Datos

# %%
# DataFrame con todos los discursos:
df_speeches = pd.read_csv('./data/us_2020_election_speeches.csv')
df_speeches
# Out:
#                    speaker                                              title  \
# 0             David Perdue  Georgia Sen. David Perdue Speech Transcript at...
# 1                Joe Biden  Joe Biden Southfield, MI Speech on Health Care...
# 2             Donald Trump  Donald Trump Speech Transcript ‘Protecting Ame...
# 3                Joe Biden      Joe Biden ABC Town Hall Transcript October 15
# 4             Donald Trump   Donald Trump NBC Town Hall Transcript October 15
# ..                     ...                                                ...
# 264         Bernie Sanders  Bernie Sanders Speech Transcript: Sanders Spea...
# 265  Democratic Candidates  Transcript: Speeches at the Iowa Caucuses – Be...
# 266           Donald Trump  Donal Trump Iowa Rally Transcript: Trump Holds...
# 267           Donald Trump  Donald Trump New Jersey Rally Speech Transcrip...
# 268  Democratic Candidates          January Iowa Democratic Debate Transcript
#
#                                                   text          date  \
# 0    David Perdue: (00:01)\nHow great is it to be b...  Oct 16, 2020
# 1    Joe Biden: (00:00)\nHello, Michigan. Hi, how a...  Oct 16, 2020
# 2    President Trump: (00:30)\nThank you. What a ni...  Oct 16, 2020
# 3    George Stephanopoulos: (00:41)\nHey, and welco...  Oct 15, 2020
# 4    Savannah Guthrie: (03:50)\nIt’s nothing but no...  Oct 15, 2020
# ..                                                 ...           ...
# 264  Bernie Sanders: (00:00)\nJust want to take thi...   Feb 6, 2020
# 265  Bernie Sanders: (00:08)\nThank you. Thank you....   Feb 4, 2020
# 266  Donald Trump: (00:24)\nI worked so hard for th...  Jan 30, 2020
# 267  Donald Trump: (01:22)\nThank you. Thank you. I...  Jan 28, 2020
# 268  Wolf Blitzer: (00:00)\nAll right, so let’s beg...  Jan 15, 2020
#
#                  location             type
# 0          Macon, Georgia  Campaign Speech
# 1    Southfield ,Michigan  Campaign Speech
# 2     Fort Myers, Florida  Campaign Speech
# 3                     ABC        Town Hall
# 4                     NBC        Town Hall
# ..                    ...              ...
# 264                  Iowa  Campaign Speech
# 265                  Iowa  Campaign Speech
# 266      Des Moines, Iowa  Campaign Speech
# 267  Wildwood, New Jersey  Campaign Speech
# 268      Des Moines, Iowa           Debate
#
# [269 rows x 6 columns]

# %% [markdown]
# ## Limpieza de Datos y
#
# ## Creación de un Dataframe con el texto de los top 3 candidatos sin encabezados

# %%
## Se reemplazan valores no informativos o ambiguos en la columna 'speaker', como "???" o "unknown", 
# por valores nulos ('NaN') para poder tratarlos correctamente en los análisis posteriores.

df_speeches["speaker"] = df_speeches["speaker"].replace(
    to_replace=r"^\?+$|^unknown$", value=pd.NA, regex=True
)

# %%
# vi) Verifico que los candidatos de Speaker aparecen en el Texto 
# a) Hallo los candidatos que aparecen como oradores en la columna texto


# ORADORES DE LA COLUMNA SPEAKER
# 1) Separar cada valor de 'speaker' por coma en columnas en un nuevo dataframe
DS_orador_from_speaker = df_speeches['speaker'].str.split(',', expand=True)

# 2) Normalizar: pasar a minúsculas y eliminar espacios al inicio
DS_orador_from_speaker = DS_orador_from_speaker.applymap(
    lambda x: x.lower().lstrip() if isinstance(x, str) else x
)
print("Orador_desde_Speaker")
print(DS_orador_from_speaker)
# Out:
# Orador_desde_Speaker
#                          0     1     2
# 0             david perdue  None  None
# 1                joe biden  None  None
# 2             donald trump  None  None
# 3                joe biden  None  None
# 4             donald trump  None  None
# ..                     ...   ...   ...
# 264         bernie sanders  None  None
# 265  democratic candidates  None  None
# 266           donald trump  None  None
# 267           donald trump  None  None
# 268  democratic candidates  None  None
#
# [269 rows x 3 columns]
# C:\Users\karin\AppData\Local\Temp\ipykernel_24152\2762154006.py:10: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   DS_orador_from_speaker = DS_orador_from_speaker.applymap(

# %%
# ###  Definición de Funciones : EXTRAER ORADORES DE LA COLUMNA TEXT

# 1) extraer nombres después de un salto de línea y antes de ": (mm:ss)"
patron = re.compile(
    r'(?<=\n)'  # Asegura que el patrón esté precedido por un salto de línea
    r'([A-ZÁÉÍÓÚÑ][\wáéíóúñ]+(?:\s+[A-ZÁÉÍÓÚÑ][\wáéíóúñ]+)*)'  # Captura nombres propios
    r'(?=\s*:\s*\(\d{1,2}:\d{2}\))'  # Lookahead para ": (mm:ss)"
)

def extraer_oradores(texto):
    if not isinstance(texto, str):
        return []
    return patron.findall(texto)

# 2. Función para normalizar y eliminar duplicados manteniendo el orden
def normalize_and_dedup(names):
    seen = set()
    out = []
    for name in names:
        nm = name.lower().strip()
        if nm not in seen:
            seen.add(nm)
            out.append(nm)
    return out

# %%
# Extraer oradores de la columna texto y guardar en un nuevo dataframe: DS_orador_from_text

# 1) Extraer listas de oradores por fila
listas = df_speeches['text'].apply(extraer_oradores)

# 2) Normalizar y quitar duplicados
listas_clean = listas.apply(normalize_and_dedup)

# 3) Construir el DataFrame final: tantas filas como df_speeches, columnas según máximo hallado
DS_orador_from_text = pd.DataFrame(listas_clean.tolist(), index=df_speeches.index)

print("Orador_desde_Text")
print(DS_orador_from_text)
# Out:
# Orador_desde_Text
#                    0                      1                2              3   \
# 0        david perdue                   None             None           None
# 1           joe biden                   None             None           None
# 2               crowd        president trump            seema   ron desantis
# 3           joe biden  george stephanopoulos     nicholas fed      kelly lee
# 4    savannah guthrie        president trump  jacqueline lugo   barbara peña
# ..                ...                    ...              ...            ...
# 264    bernie sanders                   gary             None           None
# 265    bernie sanders       elizabeth warren         audience      joe biden
# 266      donald trump           kim reynolds    sarah sanders           None
# 267      donald trump                  crowd    jeff van drew           None
# 268    bernie sanders           wolf blitzer        joe biden  amy klobuchar
#
#                  4              5                         6   \
# 0              None           None                      None
# 1              None           None                      None
# 2              None           None                      None
# 3    anthony archer     voice over           cedric humphrey
# 4     isabella peña       savannah  cristy montesinos alonso
# ..              ...            ...                       ...
# 264            None           None                      None
# 265  pete buttigieg  amy klobuchar               andrew yang
# 266            None           None                      None
# 267            None           None                      None
# 268  pete buttigieg     tom steyer              abby phillip
#
#                         7                   8              9   ...    47  \
# 0                     None                None           None  ...  None
# 1                     None                None           None  ...  None
# 2                     None                None           None  ...  None
# 3    george stephanopoulus  angelia politarhos  nathan osburn  ...  None
# 4            adam schucher        moriah geene    cindy velez  ...  None
# ..                     ...                 ...            ...  ...   ...
# 264                   None                None           None  ...  None
# 265                  crowd                None           None  ...  None
# 266                   None                None           None  ...  None
# 267                   None                None           None  ...  None
# 268                   None                None           None  ...  None
#
#        48    49    50    51    52    53    54    55    56
# 0    None  None  None  None  None  None  None  None  None
# 1    None  None  None  None  None  None  None  None  None
# 2    None  None  None  None  None  None  None  None  None
# 3    None  None  None  None  None  None  None  None  None
# 4    None  None  None  None  None  None  None  None  None
# ..    ...   ...   ...   ...   ...   ...   ...   ...   ...
# 264  None  None  None  None  None  None  None  None  None
# 265  None  None  None  None  None  None  None  None  None
# 266  None  None  None  None  None  None  None  None  None
# 267  None  None  None  None  None  None  None  None  None
# 268  None  None  None  None  None  None  None  None  None
#
# [269 rows x 57 columns]

# %%
#   COMPARO ORADORES DE COLUMNA SPEAKER CON ORADORES DE COLUMNA TEXT Y REGISTRA DIFERENCIAS:

#  - DS_orador_from_speaker: DataFrame ancho con columnas 0,1,2… de oradores esperados
#  - DS_orador_from_text:    DataFrame ancho con columnas 0,1,2… de oradores extraídos

rows = []  # aquí acumularemos [fila, missing1, missing2, ...]

for idx in DS_orador_from_speaker.index:
    # 1) Lista de oradores esperados en esta fila (sin NaN, ya normalizados)
    expected = [v for v in DS_orador_from_speaker.loc[idx].tolist() if isinstance(v, str)]
    # 2) Lista de oradores detectados en el texto para esta misma fila
    detected = [v for v in DS_orador_from_text.loc[idx].tolist() if isinstance(v, str)]
    # 3) Identificar los que faltan
    missing = [s for s in expected if s not in detected]
    # 4) Si hay alguno faltante, lo agregamos junto con el índice
    if missing:
        rows.append([idx] + missing)

print(rows)
print(f"Hay {len(rows)} filas con diferencias entre los speakers de la columna 'speaker' y los extraídos de la columna 'text")
# Out:
# [[2, 'donald trump'], [4, 'donald trump'], [7, 'donald trump'], [10, 'donald trump'], [14, 'joe biden'], [16, 'mike pence'], [20, 'jaime harrison'], [22, 'donald trump'], [24, 'mike pence'], [25, 'donald trump'], [35, 'barack obama'], [39, 'mike pence'], [42, 'joe biden'], [46, 'donald trump', 'joe biden'], [62, 'donald trump'], [64, 'mike pence'], [65, 'donald trump'], [76, 'kamala harris'], [77, 'mike pence'], [82, 'donald trump'], [85, 'donald trump'], [87, 'donald trump'], [96, 'donald trump'], [100, 'joe biden'], [105, 'donald trump'], [106, 'multiple speakers'], [107, 'donald trump'], [113, 'kamala harris'], [114, 'multiple speakers'], [116, 'mike pence'], [124, 'multiple speakers'], [132, 'multiple speakers'], [136, 'donald trump jr.'], [140, 'multiple speakers'], [143, 'sarah cooper'], [157, 'jill biden'], [160, 'alexandria ocasio-cortez'], [168, 'gretchen whitmer'], [172, 'donald trump'], [173, 'mike pence'], [177, 'mike pence'], [183, 'kamala harris'], [184, 'joe biden', 'barack obama'], [187, 'joe biden'], [197, 'amy klobuchar'], [201, 'tom wolf'], [202, 'val demings'], [228, 'joe biden'], [234, 'democratic candidates'], [237, 'o’rourke'], [244, 'democratic candidates'], [246, 'democratic candidates'], [252, 'democratic candidates'], [255, 'democratic candidates'], [262, 'democratic candidates'], [265, 'democratic candidates'], [268, 'democratic candidates']]
# Hay 57 filas con diferencias entre los speakers de la columna 'speaker' y los extraídos de la columna 'text

# %%
# 5) Crear el DataFrame de discrepancias
#    La primera columna es 'row_index', las siguientes se nombran automáticamente 0,1,2…
DF_speaker_vs_text = pd.DataFrame(rows, columns=['row_index'] + 
                                  [f'missing_{i+1}' for i in range(max(len(r)-1 for r in rows))])

# En las filas indicadas a continuación, el orador de Speaker no se halla en el Texto correspondiente
print("Speaker_vs_Text")
print(DF_speaker_vs_text)
# Out:
# Speaker_vs_Text
#     row_index                 missing_1     missing_2
# 0           2              donald trump          None
# 1           4              donald trump          None
# 2           7              donald trump          None
# 3          10              donald trump          None
# 4          14                 joe biden          None
# 5          16                mike pence          None
# 6          20            jaime harrison          None
# 7          22              donald trump          None
# 8          24                mike pence          None
# 9          25              donald trump          None
# 10         35              barack obama          None
# 11         39                mike pence          None
# 12         42                 joe biden          None
# 13         46              donald trump     joe biden
# 14         62              donald trump          None
# 15         64                mike pence          None
# 16         65              donald trump          None
# 17         76             kamala harris          None
# 18         77                mike pence          None
# 19         82              donald trump          None
# 20         85              donald trump          None
# 21         87              donald trump          None
# 22         96              donald trump          None
# 23        100                 joe biden          None
# 24        105              donald trump          None
# 25        106         multiple speakers          None
# 26        107              donald trump          None
# 27        113             kamala harris          None
# 28        114         multiple speakers          None
# 29        116                mike pence          None
# 30        124         multiple speakers          None
# 31        132         multiple speakers          None
# 32        136          donald trump jr.          None
# 33        140         multiple speakers          None
# 34        143              sarah cooper          None
# 35        157                jill biden          None
# 36        160  alexandria ocasio-cortez          None
# 37        168          gretchen whitmer          None
# 38        172              donald trump          None
# 39        173                mike pence          None
# 40        177                mike pence          None
# 41        183             kamala harris          None
# 42        184                 joe biden  barack obama
# 43        187                 joe biden          None
# 44        197             amy klobuchar          None
# 45        201                  tom wolf          None
# 46        202               val demings          None
# 47        228                 joe biden          None
# 48        234     democratic candidates          None
# 49        237                  o’rourke          None
# 50        244     democratic candidates          None
# 51        246     democratic candidates          None
# 52        252     democratic candidates          None
# 53        255     democratic candidates          None
# 54        262     democratic candidates          None
# 55        265     democratic candidates          None
# 56        268     democratic candidates          None

# %%
# Crear DF_Oradores_Text_NoSpeaker tomando de DS_orador_from_text
DF_Oradores_Text_NoSpeaker = DS_orador_from_text.loc[
    DF_speaker_vs_text['row_index']
].copy()

# Insertar como primera columna el índice de fila de Speaker_vs_Text
DF_Oradores_Text_NoSpeaker.insert(
    0,
    'row_index',
    DF_speaker_vs_text['row_index'].values
)

print("Oradores que aparecen en Text y que no aparecen en Speaker")
print(DF_Oradores_Text_NoSpeaker)
# Out:
# Oradores que aparecen en Text y que no aparecen en Speaker
#      row_index                           0                                1  \
# 2            2                       crowd                  president trump
# 4            4            savannah guthrie                  president trump
# 7            7                    audience                            crowd
# 10          10             president trump                            crowd
# 14          14    vice president joe biden                             None
# 16          16   vice president mike pence                         audience
# 20          20              lindsey graham                   jamie harrison
# 22          22      president donald trump                     sean hannity
# 24          24   vice president mike pence                         audience
# 25          25                       maria                  president trump
# 35          35                        None                             None
# 39          39                  ben carson        vice president mike pence
# 42          42                  jill biden                            crowd
# 46          46               chris wallace         vice president joe biden
# 62          62                       crowd           president donald trump
# 64          64                    audience        vice president mike pence
# 65          65                       crowd                      larry obhof
# 76          76       senator kamala harris                  cherelle parker
# 77          77                       crowd        vice president mike pence
# 82          82                    audience                       kelli ward
# 85          85                    audience           president donald trump
# 87          87                       crowd                             None
# 96          96                    audience                             None
# 100        100    vice president joe biden                             None
# 105        105             president trump                            crowd
# 106        106                donald trump                  franklin graham
# 107        107      president donald trump                         audience
# 113        113       senator kamala harris                             None
# 114        114                 kristi noem                 marsha blackburn
# 116        116   vice president mike pence                            crowd
# 124        124                  jon ponder                   richard beasly
# 132        132                charlie kirk               rebecca friedrichs
# 136        136                        None                             None
# 140        140            kerry washington                   bernie sanders
# 143        143                        None                             None
# 157        157                   joe biden                             None
# 160        160                        None                             None
# 168        168   governor gretchen whitmer                             None
# 172        172      president donald trump                    rudy giuliani
# 173        173   vice president mike pence                          jessica
# 177        177   vice president mike pence                             None
# 183        183              senator harris  representative carla cunningham
# 184        184             president obama         vice president joe biden
# 187        187                 aysha ahmed                       nihad awad
# 197        197       senator amy klobuchar                             None
# 201        201           governor tom wolf                        joe biden
# 202        202  representative val demings                 stephanie miller
# 228        228                   sade reed                      mike duggan
# 234        234                   joe biden                   bernie sanders
# 237        237                    audience                   pete buttigieg
# 244        244                  gayle king                   bernie sanders
# 246        246              bernie sanders                         audience
# 252        252                 lester holt                   bernie sanders
# 255        255                    audience                   bernie sanders
# 262        262                   joe biden                   bernie sanders
# 265        265              bernie sanders                 elizabeth warren
# 268        268              bernie sanders                     wolf blitzer
#
#                        2                         3                 4  \
# 2                  seema              ron desantis              None
# 4        jacqueline lugo              barbara peña     isabella peña
# 7                   None                      None              None
# 10              audience                      None              None
# 14                  None                      None              None
# 16                  None                      None              None
# 20              amy wood               gordon dill    carolyn murray
# 22                  None                      None              None
# 24                  None                      None              None
# 25                  None                      None              None
# 35                  None                      None              None
# 39                  None                      None              None
# 42           brian smith  vice president joe biden              None
# 46                  None                      None              None
# 62              audience                      None              None
# 64                  None                      None              None
# 65           jane timken                      None              None
# 76              audience                    cheryl     latifa fields
# 77                  None                      None              None
# 82                  arte                    gloria      jimmy chavez
# 85        justin gaethje                      None              None
# 87                  None                      None              None
# 96                  None                      None              None
# 100                 None                      None              None
# 105                 None                      None              None
# 106       kevin mccarthy             jeff van drew          michelle
# 107                 None                      None              None
# 113                 None                      None              None
# 114         dan crenshaw             keith kellogg        tera myers
# 116                 None                      None              None
# 124         donald trump              jamie ponder    richard blakey
# 132       tanya weinreis                matt gaetz        kim klacik
# 136                 None                      None              None
# 140       michelle obama         tracee ellis ross         joe biden
# 143                 None                      None              None
# 157                 None                      None              None
# 160                 None                      None              None
# 168                 None                      None              None
# 172                crowd                      None              None
# 173        devin sanders               todd perdue         jen fogle
# 177                 None                      None              None
# 183     cassandra brooks                      None              None
# 184                 None                      None              None
# 187        linda sarsour              rizwan hasan     khurrum wahid
# 197                 None                      None              None
# 201                 None                      None              None
# 202                 None                      None              None
# 228      brenda lawrence          garlin gilchrist             crowd
# 234     elizabeth warren            mike bloomberg              None
# 237  yes\npete buttigieg               chris hayes         joe biden
# 244       mike bloomberg            pete buttigieg  elizabeth warren
# 246            joe biden           pete buttigieig     amy klobucher
# 252     elizabeth warren         michael bloomberg     amy klobuchar
# 255     elizabeth warren            pete buttigieg     amy klobuchar
# 262        amy klobuchar                tom steyer       andrew yang
# 265             audience                 joe biden    pete buttigieg
# 268            joe biden             amy klobuchar    pete buttigieg
#
#                         5                         6  \
# 2                    None                      None
# 4                savannah  cristy montesinos alonso
# 7                    None                      None
# 10                   None                      None
# 14                   None                      None
# 16                   None                      None
# 20           louis yuhasz                      None
# 22                   None                      None
# 24                   None                      None
# 25                   None                      None
# 35                   None                      None
# 39                   None                      None
# 42                   None                      None
# 46                   None                      None
# 62                   None                      None
# 64                   None                      None
# 65                   None                      None
# 76            selema pace                    evelyn
# 77                   None                      None
# 82            jorge rivas             moses sanchez
# 85                   None                      None
# 87                   None                      None
# 96                   None                      None
# 100                  None                      None
# 105                  None                      None
# 106      stacia brightmon               dan scavino
# 107                  None                      None
# 113                  None                      None
# 114      kayleigh mcenany               karen pence
# 116                  None                      None
# 124             rand paul               jason joyce
# 132        ronna mcdaniel              donald trump
# 136                  None                      None
# 140          nancy pelosi            hilary clinton
# 143                  None                      None
# 157                  None                      None
# 160                  None                      None
# 168                  None                      None
# 172                  None                      None
# 173                  None                      None
# 177                  None                      None
# 183                  None                      None
# 184                  None                      None
# 187  vice president biden                      None
# 197                  None                      None
# 201                  None                      None
# 202                  None                      None
# 228             announcer            michael bivins
# 234                  None                      None
# 237                 crowd             amy klobuchar
# 244            tom steyer                 joe biden
# 246      elizabeth warren                      None
# 252             joe biden            pete buttigieg
# 255                  None                      None
# 262      elizabeth warren            pete buttigieg
# 265         amy klobuchar               andrew yang
# 268            tom steyer              abby phillip
#
#                              7                  8  ...           47    48  \
# 2                         None               None  ...         None  None
# 4                adam schucher       moriah geene  ...         None  None
# 7                         None               None  ...         None  None
# 10                        None               None  ...         None  None
# 14                        None               None  ...         None  None
# 16                        None               None  ...         None  None
# 20                        None               None  ...         None  None
# 22                        None               None  ...         None  None
# 24                        None               None  ...         None  None
# 25                        None               None  ...         None  None
# 35                        None               None  ...         None  None
# 39                        None               None  ...         None  None
# 42                        None               None  ...         None  None
# 46                        None               None  ...         None  None
# 62                        None               None  ...         None  None
# 64                        None               None  ...         None  None
# 65                        None               None  ...         None  None
# 76                      lasora               None  ...         None  None
# 77                        None               None  ...         None  None
# 82       leah marquez peterson          pam kirby  ...         None  None
# 85                        None               None  ...         None  None
# 87                        None               None  ...         None  None
# 96                        None               None  ...         None  None
# 100                       None               None  ...         None  None
# 105                       None               None  ...         None  None
# 106            mitch mcconnell         dana white  ...         None  None
# 107                       None               None  ...         None  None
# 113                       None               None  ...         None  None
# 114           kellyanne conway  sister dede byrne  ...         None  None
# 116                       None               None  ...         None  None
# 124              chris pearson       larry kudlow  ...         None  None
# 132                   amy ford               None  ...         None  None
# 136                       None               None  ...         None  None
# 140               barack obama      kamala harris  ...  deb haaland  sara
# 143                       None               None  ...         None  None
# 157                       None               None  ...         None  None
# 160                       None               None  ...         None  None
# 168                       None               None  ...         None  None
# 172                       None               None  ...         None  None
# 173                       None               None  ...         None  None
# 177                       None               None  ...         None  None
# 183                       None               None  ...         None  None
# 184                       None               None  ...         None  None
# 187                       None               None  ...         None  None
# 197                       None               None  ...         None  None
# 201                       None               None  ...         None  None
# 202                       None               None  ...         None  None
# 228  governor gretchen whitmer        cory booker  ...         None  None
# 234                       None               None  ...         None  None
# 237                       None               None  ...         None  None
# 244              amy klobuchar      bill whitaker  ...         None  None
# 246                       None               None  ...         None  None
# 252             hallie jackson         chuck todd  ...         None  None
# 255                       None               None  ...         None  None
# 262                    lindsey         david muir  ...         None  None
# 265                      crowd               None  ...         None  None
# 268                       None               None  ...         None  None
#
#         49     50       51    52       53            54            55  \
# 2     None   None     None  None     None          None          None
# 4     None   None     None  None     None          None          None
# 7     None   None     None  None     None          None          None
# 10    None   None     None  None     None          None          None
# 14    None   None     None  None     None          None          None
# 16    None   None     None  None     None          None          None
# 20    None   None     None  None     None          None          None
# 22    None   None     None  None     None          None          None
# 24    None   None     None  None     None          None          None
# 25    None   None     None  None     None          None          None
# 35    None   None     None  None     None          None          None
# 39    None   None     None  None     None          None          None
# 42    None   None     None  None     None          None          None
# 46    None   None     None  None     None          None          None
# 62    None   None     None  None     None          None          None
# 64    None   None     None  None     None          None          None
# 65    None   None     None  None     None          None          None
# 76    None   None     None  None     None          None          None
# 77    None   None     None  None     None          None          None
# 82    None   None     None  None     None          None          None
# 85    None   None     None  None     None          None          None
# 87    None   None     None  None     None          None          None
# 96    None   None     None  None     None          None          None
# 100   None   None     None  None     None          None          None
# 105   None   None     None  None     None          None          None
# 106   None   None     None  None     None          None          None
# 107   None   None     None  None     None          None          None
# 113   None   None     None  None     None          None          None
# 114   None   None     None  None     None          None          None
# 116   None   None     None  None     None          None          None
# 124   None   None     None  None     None          None          None
# 132   None   None     None  None     None          None          None
# 136   None   None     None  None     None          None          None
# 140  terry  james  seymour   pat  jeffrey  donald trump  alex padilla
# 143   None   None     None  None     None          None          None
# 157   None   None     None  None     None          None          None
# 160   None   None     None  None     None          None          None
# 168   None   None     None  None     None          None          None
# 172   None   None     None  None     None          None          None
# 173   None   None     None  None     None          None          None
# 177   None   None     None  None     None          None          None
# 183   None   None     None  None     None          None          None
# 184   None   None     None  None     None          None          None
# 187   None   None     None  None     None          None          None
# 197   None   None     None  None     None          None          None
# 201   None   None     None  None     None          None          None
# 202   None   None     None  None     None          None          None
# 228   None   None     None  None     None          None          None
# 234   None   None     None  None     None          None          None
# 237   None   None     None  None     None          None          None
# 244   None   None     None  None     None          None          None
# 246   None   None     None  None     None          None          None
# 252   None   None     None  None     None          None          None
# 255   None   None     None  None     None          None          None
# 262   None   None     None  None     None          None          None
# 265   None   None     None  None     None          None          None
# 268   None   None     None  None     None          None          None
#
#                  56
# 2              None
# 4              None
# 7              None
# 10             None
# 14             None
# 16             None
# 20             None
# 22             None
# 24             None
# 25             None
# 35             None
# 39             None
# 42             None
# 46             None
# 62             None
# 64             None
# 65             None
# 76             None
# 77             None
# 82             None
# 85             None
# 87             None
# 96             None
# 100            None
# 105            None
# 106            None
# 107            None
# 113            None
# 114            None
# 116            None
# 124            None
# 132            None
# 136            None
# 140  jocelyn benson
# 143            None
# 157            None
# 160            None
# 168            None
# 172            None
# 173            None
# 177            None
# 183            None
# 184            None
# 187            None
# 197            None
# 201            None
# 202            None
# 228            None
# 234            None
# 237            None
# 244            None
# 246            None
# 252            None
# 255            None
# 262            None
# 265            None
# 268            None
#
# [57 rows x 58 columns]

# %%
# Obtener la Lista ordenada de oradores que aparecen en la columna 'speaker'

# PARA TRABAJAR UNIFICANDO/NORMALIZANDO LOS NOMBRES QUE MÁS APARECEN 
# SE CUENTA DE MAYOR A MENOR LA CANTIDAD DE VECES QUE APARECE UN NOMBRE ES SPEAKER 

# 1) Para cada fila, tomar los valores no nulos y quedarnos con los únicos
unique_per_row = DS_orador_from_speaker.apply(
    lambda row: pd.Series(row.dropna().unique()).tolist(),
    axis=1
)

# 2) Aplanar todas esas listas y contar ocurrencias de cada orador
counter = Counter(chain.from_iterable(unique_per_row))

# 3) Crear el DataFrame ordenado con dos columnas: 'orador' y 'count'
Lista_ordenada_oradores_Speaker = (
    pd.DataFrame(counter.items(), columns=['orador', 'count'])
      .sort_values('count', ascending=False)
      .reset_index(drop=True)
)

# Resultado
print("Lista_ordenada_oradores_Speaker")
print(Lista_ordenada_oradores_Speaker)
# Out:
# Lista_ordenada_oradores_Speaker
#                 orador  count
# 0            joe biden     81
# 1         donald trump     54
# 2           mike pence     20
# 3       bernie sanders     17
# 4        kamala harris     16
# ..                 ...    ...
# 60           rand paul      1
# 61           tim scott      1
# 62  kimberly guilfoyle      1
# 63     herschel walker      1
# 64            o’rourke      1
#
# [65 rows x 2 columns]

# %%
# Obtener la Lista ordenada de oradores que aparecen en la columna 'text'

# IDEM ANTERIOR CON ORADORES DESDE TEXT

# 1) Para cada fila de DS_orador_from_text, tomar los oradores no nulos y únicos
unique_per_row_text = DS_orador_from_text.apply(
    lambda row: pd.Series(row.dropna().unique()).tolist(),
    axis=1
)

# 2) Aplanar todas esas listas y contar ocurrencias de cada orador
counter_text = Counter(chain.from_iterable(unique_per_row_text))

# 3) Crear el DataFrame ordenado con dos columnas: 'orador' y 'count'
Lista_ordenada_oradores_Text = (
    pd.DataFrame(counter_text.items(), columns=['orador', 'count'])
      .sort_values('count', ascending=False)
      .reset_index(drop=True)
)

# Resultado
print("Lista_ordenada_oradores_Text")
print(Lista_ordenada_oradores_Text.to_string())
# Out:
# Lista_ordenada_oradores_Text
#                               orador  count
# 0                          joe biden     92
# 1                       donald trump     43
# 2                              crowd     36
# 3                           audience     35
# 4                     bernie sanders     27
# 5                      kamala harris     17
# 6                         mike pence     13
# 7                   elizabeth warren     12
# 8                     pete buttigieg     11
# 9          vice president mike pence      8
# 10                     amy klobuchar      7
# 11                       andrew yang      6
# 12          vice president joe biden      5
# 13            president donald trump      5
# 14                    mike bloomberg      5
# 15                      barack obama      5
# 16                   president trump      5
# 17                    lindsey graham      4
# 18                       cory booker      4
# 19                           jessica      4
# 20                    michelle obama      3
# 21                        tom steyer      3
# 22                        jill biden      3
# 23             senator kamala harris      3
# 24             senator amy klobuchar      3
# 25                      nancy pelosi      3
# 26                   hillary clinton      3
# 27                 nicholas sandmann      2
# 28                    mari manoogian      2
# 29                         tom perez      2
# 30                      andrew cuomo      2
# 31                     jim roosevelt      2
# 32                        dana white      2
# 33                     eric garcetti      2
# 34                    bernie comfort      2
# 35                  scott richardson      2
# 36                              mary      2
# 37                   mitch mcconnell      2
# 38                     chris wallace      2
# 39                      colin powell      2
# 40                     jeff van drew      2
# 41                              gary      2
# 42                        ben carson      2
# 43                              john      2
# 44                     rudy giuliani      2
# 45                      dan crenshaw      2
# 46                 tracee ellis ross      2
# 47                              mike      2
# 48                         pam bondi      2
# 49                         rand paul      2
# 50                               rob      2
# 51                            lauren      2
# 52                   anderson cooper      2
# 53                     stacey abrams      2
# 54                         lou holtz      2
# 55                  kellyanne conway      2
# 56                  kayleigh mcenany      2
# 57         governor gretchen whitmer      2
# 58                        doug ducey      2
# 59                    ronna mcdaniel      2
# 60                         tim scott      2
# 61                  garlin gilchrist      2
# 62                       karen pence      2
# 63                  kerry washington      2
# 64                           jeffrey      2
# 65                      cindy mccain      2
# 66                     julian castro      2
# 67                             terry      2
# 68                  savannah guthrie      2
# 69                       lester holt      2
# 70                 michael bloomberg      2
# 71                      sean hannity      2
# 72                            female      2
# 73                       brian smith      2
# 74                       chris hayes      2
# 75                     chuck schumer      2
# 76                    hallie jackson      2
# 77                    yvanna cancela      2
# 78             george stephanopoulos      2
# 79                    jaime harrison      2
# 80                             group      2
# 81                      bill clinton      2
# 82                     nury martinez      1
# 83                             janet      1
# 84                    kathleen clyde      1
# 85                     william daley      1
# 86                          sam park      1
# 87                    denny ruprecht      1
# 88                     robert garcia      1
# 89                    marlon kimpson      1
# 90                     greg anderson      1
# 91                        mary bruce      1
# 92                  priscilla castro      1
# 93                        rick lucas      1
# 94                     pedro pizarro      1
# 95                        conor lamb      1
# 96                             randy      1
# 97                  malcolm kenyatta      1
# 98                  alfredo corchado      1
# 99                      tia mitchell      1
# 100                     jonathan nez      1
# 101                    errol barnett      1
# 102            christina kolbjornsen      1
# 103                         bob king      1
# 104                 cassandra brooks      1
# 105                   senator harris      1
# 106  representative carla cunningham      1
# 107                       nihad awad      1
# 108                      aysha ahmed      1
# 109                     peggy vonner      1
# 110                     barney frank      1
# 111                  adriana alvarez      1
# 112           julie chavez rodriguez      1
# 113                  denis mcdonough      1
# 114                  marlyn hoilette      1
# 115                   mary kay henry      1
# 116                    daniel inouye      1
# 117             tsoganesh endogoshet      1
# 118                      chris ellis      1
# 119                  vivian deniston      1
# 120                      mario cuomo      1
# 121                    perla canales      1
# 122                     pamela owens      1
# 123                        bobby roy      1
# 124                     debra dawson      1
# 125                    rhonda miller      1
# 126                         nimo ali      1
# 127                     terry thomas      1
# 128                     matt yarnell      1
# 129                  shanrika nelson      1
# 130                     ann richards      1
# 131                  president obama      1
# 132                        jen fogle      1
# 133                      nikki fried      1
# 134                    arturo vargas      1
# 135                     colin allred      1
# 136                      todd perdue      1
# 137                   lori lightfoot      1
# 138                             nick      1
# 139                     rizwan hasan      1
# 140                     leon bridges      1
# 141                  philonise floyd      1
# 142                    muriel bowser      1
# 143                        cameraman      1
# 144                  derrick johnson      1
# 145                       gwen moore      1
# 146                   michelle beebe      1
# 147                      rick telesz      1
# 148                      marley dias      1
# 149                 caroline kennedy      1
# 150                     eva longoria      1
# 151                 gabriel salguero      1
# 152                            intro      1
# 153                 jack schlossberg      1
# 154                        ron klain      1
# 155                    cecilia munoz      1
# 156                      ted kaufman      1
# 157                  rosalynn carter      1
# 158                      john mccain      1
# 159             lisa blunt rochester      1
# 160                      chris coons      1
# 161                     jimmy carter      1
# 162                  jacquelyn asbie      1
# 163                    jamira burley      1
# 164                      art acevedo      1
# 165                   victoria neave      1
# 166                        gwen carr      1
# 167                    devin sanders      1
# 168                  randall woodfin      1
# 169                        tom emmer      1
# 170                     ashley biden      1
# 171                    brendan boyle      1
# 172                      john kasich      1
# 173                          annette      1
# 174                    maggie rogers      1
# 175                      sara gideon      1
# 176                   raumesh akbari      1
# 177                            rhoda      1
# 178                   matthew miller      1
# 179                        elizabeth      1
# 180                      sally yates      1
# 181                         victoria      1
# 182                   michelle boyle      1
# 183                    aldo martinez      1
# 184                        trung lee      1
# 185                            micah      1
# 186                           denise      1
# 187                    megan rapinoe      1
# 188                  kristin urquiza      1
# 189                       kevin penn      1
# 190                      jim clyburn      1
# 191                             sina      1
# 192                    linda sarsour      1
# 193                      daphne kwok      1
# 194                    khurrum wahid      1
# 195                      mike duggan      1
# 196                    tulsi gabbard      1
# 197                        dana bash      1
# 198                    ilia calderón      1
# 199                      jake tapper      1
# 200                   amy langenfeld      1
# 201                        reporters      1
# 202                        sade reed      1
# 203                  brenda lawrence      1
# 204             vice president biden      1
# 205                        announcer      1
# 206                   michael bivins      1
# 207                     sandra smith      1
# 208                    donna brazile      1
# 209                         ed henry      1
# 210                      thom tillis      1
# 211              yes\npete buttigieg      1
# 212                          arlette      1
# 213                  alexandra jaffe      1
# 214                      gabe fisher      1
# 215                      jen epstein      1
# 216                    michelle kwan      1
# 217                          al gore      1
# 218                    shervin jones      1
# 219                  safaa elzakzoky      1
# 220                      jerry brown      1
# 221                    shevrin jones      1
# 222                     kris holtham      1
# 223                   lavette jacobs      1
# 224                             judy      1
# 225                      leah dudley      1
# 226                            frank      1
# 227                   ken washington      1
# 228                      bill barrow      1
# 229                     jessica dean      1
# 230                 trevor hunnicutt      1
# 231                   henry mcmaster      1
# 232                       gayle king      1
# 233                    bill whitaker      1
# 234                              amy      1
# 235                   anders helberg      1
# 236                          sanders      1
# 237                             macy      1
# 238                           judith      1
# 239                            april      1
# 240                     jane sanders      1
# 241             congresswoman kuster      1
# 242                          lindsey      1
# 243                       david muir      1
# 244                 monica hernandez      1
# 245                      adam sexton      1
# 246                     linsey davis      1
# 247                     kim reynolds      1
# 248                    sarah sanders      1
# 249                     wolf blitzer      1
# 250                            nancy      1
# 251                 audience members      1
# 252                    major garrett      1
# 253                           rhonda      1
# 254                 margaret brennan      1
# 255                  pete buttigieig      1
# 256                    amy klobucher      1
# 257                    mike eruzione      1
# 258                        jim craig      1
# 259                     kelly brooks      1
# 260              governor doug ducey      1
# 261                   martha mcsally      1
# 262                       chuck todd      1
# 263                        moderator      1
# 264                     vanessa hauc      1
# 265                      jon ralston      1
# 266                            helen      1
# 267                            scott      1
# 268                            brett      1
# 269                  carlia alderman      1
# 270                    steve mnuchin      1
# 271                              joe      1
# 272                    khelan bhatia      1
# 273        represenative mark takano      1
# 274   representative tammy duckworth      1
# 275          representative ted lieu      1
# 276   representative pramila jayapal      1
# 277          representative andy kim      1
# 278                    jong vang tao      1
# 279                  vimila rejenjun      1
# 280                          kirsten      1
# 281                      don cheadle      1
# 282                        nila cobb      1
# 283                      ryan wilson      1
# 284                  jameesha harris      1
# 285                      keith james      1
# 286                governor tom wolf      1
# 287       representative val demings      1
# 288                         judy chu      1
# 289                  lorraine miller      1
# 290                         ron kind      1
# 291                     stephen gong      1
# 292                       kanye west      1
# 293                           summer      1
# 294                          georgia      1
# 295                           shiloh      1
# 296                           kaylee      1
# 297                       mary trump      1
# 298                      james comey      1
# 299                    lily eskelsen      1
# 300         turquoise lejeune parker      1
# 301                            paula      1
# 302                       jimbo lamb      1
# 303                             alex      1
# 304                       amna nawaz      1
# 305                     vicky nguyen      1
# 306                   christine chen      1
# 307                 stephanie miller      1
# 308                    mary freibert      1
# 309                            moise      1
# 310                  sindy benavides      1
# 311                 martha maccallum      1
# 312                      shayna cruz      1
# 313                       sara polon      1
# 314                      danny lemos      1
# 315                   kristen murray      1
# 316                  rebecca johnson      1
# 317                  leslie coffield      1
# 318                             dena      1
# 319                     carol mcneil      1
# 320                        mary rose      1
# 321                             mark      1
# 322                  carolyn perkins      1
# 323                secretary mnuchin      1
# 324                  kylie patterson      1
# 325                     phil tulkoff      1
# 326                       bret baier      1
# 327                   joaquin castro      1
# 328                              ron      1
# 329                chairman thompson      1
# 330                       rob grover      1
# 331                 gretchen whitmer      1
# 332                      phil murphy      1
# 333                       ned lamont      1
# 334                marvin zanders ii      1
# 335                     jaylen geist      1
# 336                    veronica ward      1
# 337                             leta      1
# 338               congressman lawson      1
# 339                   domingo garcia      1
# 340                   nancy feregoso      1
# 341                        alejandro      1
# 342                          edgardo      1
# 343        congresswoman zoe lofgren      1
# 344                     filemon vela      1
# 345                    maria cardona      1
# 346                     david perdue      1
# 347                  bennie thompson      1
# 348                    brian mueller      1
# 349              marloshawn franklin      1
# 350                      larry obhof      1
# 351                      jane timken      1
# 352                     mark meadows      1
# 353                     daniel garza      1
# 354                  jovita carranza      1
# 355                     janet mendez      1
# 356                      selema pace      1
# 357                   governor ducey      1
# 358               senator tina smith      1
# 359                  matt campanario      1
# 360                    hannah cannon      1
# 361                  cherelle parker      1
# 362                           cheryl      1
# 363                    james johnson      1
# 364                 jeremiah wheeler      1
# 365           rajon williams jackson      1
# 366                  wendell anthony      1
# 367                   malcolm graham      1
# 368                     andrea brown      1
# 369                 hannah bonaparte      1
# 370                       chris paul      1
# 371                   mayor vi lyles      1
# 372                   fabio andretti      1
# 373                carolina ferreiro      1
# 374                      hiram turil      1
# 375                 carla salvatiras      1
# 376                          claudia      1
# 377                             juan      1
# 378                            erica      1
# 379                         santiago      1
# 380                    latifa fields      1
# 381                           evelyn      1
# 382                      tom barrett      1
# 383                   crystal wagars      1
# 384                     jimmy chavez      1
# 385                      jorge rivas      1
# 386                    moses sanchez      1
# 387            leah marquez peterson      1
# 388                        pam kirby      1
# 389                   justin gaethje      1
# 390                 frederica wilson      1
# 391                           lasora      1
# 392                     eric knowles      1
# 393                  jaffus hardrick      1
# 394                    rhonda thomas      1
# 395                    ruben roberts      1
# 396                   richard trumka      1
# 397                             rich      1
# 398                           gloria      1
# 399                             arte      1
# 400                       kelli ward      1
# 401                    deshaun hienz      1
# 402                    lauren weiner      1
# 403                        alexandra      1
# 404                     jim roudeski      1
# 405                       commercial      1
# 406                   ellesia blaque      1
# 407                   leah schwotzer      1
# 408                  pastor carl day      1
# 409                     laura galvis      1
# 410                    johnny powell      1
# 411                       julie bard      1
# 412                     paul tubiana      1
# 413                         meredith      1
# 414                          caitlin      1
# 415                      joe gruters      1
# 416                       angela rye      1
# 417                 chairman russell      1
# 418                       toby feuer      1
# 419                     moriah geene      1
# 420                      cindy velez      1
# 421                    paulette dale      1
# 422                     david rouzer      1
# 423                pedro fuentes cid      1
# 424                  damian ferguson      1
# 425                   jamie harrison      1
# 426                    lottie joiner      1
# 427                         amy wood      1
# 428                      gordon dill      1
# 429                   carolyn murray      1
# 430                     louis yuhasz      1
# 431                            maria      1
# 432                       susan page      1
# 433                    adam schucher      1
# 434         cristy montesinos alonso      1
# 435                         savannah      1
# 436                    isabella peña      1
# 437                     barbara peña      1
# 438                  jacqueline lugo      1
# 439                     andrew lewis      1
# 440                    nathan osburn      1
# 441               angelia politarhos      1
# 442            george stephanopoulus      1
# 443                  cedric humphrey      1
# 444                       voice over      1
# 445                   anthony archer      1
# 446                        kelly lee      1
# 447                     nicholas fed      1
# 448                     ron desantis      1
# 449                            seema      1
# 450                  vanessa tamariz      1
# 451                         jonathan      1
# 452                  nicolle wallace      1
# 453                    frank spencer      1
# 454                  kamilia landrum      1
# 455                         herschel      1
# 456                   keisha bottoms      1
# 457                         pat yoes      1
# 458                     pete hegseth      1
# 459                       lynn kerry      1
# 460                    robin sanders      1
# 461                       lori jones      1
# 462                      marcus bass      1
# 463                     lavon barnes      1
# 464                   devonte wilson      1
# 465                    tiffany davis      1
# 466                  marvin mcmickle      1
# 467                   james callahan      1
# 468                     matt hoffman      1
# 469            michelle cruz marrero      1
# 470                    steve sisolak      1
# 471                       dina titus      1
# 472                      adam mencer      1
# 473                    alonzo julian      1
# 474                   richard rogers      1
# 475                       mike cihla      1
# 476                    eric weisfeld      1
# 477                       joe bustos      1
# 478                      bill sharpe      1
# 479                   peter gonzalez      1
# 480                   ismael illiano      1
# 481                  danny lavendera      1
# 482                        hota kotb      1
# 483                    nicole maddox      1
# 484                     corey birkel      1
# 485                    kennita jones      1
# 486                     alicia urena      1
# 487                  brittney hubert      1
# 488                      danica roem      1
# 489                     robyn senior      1
# 490                    miyoko hikiji      1
# 491                 vilissa thompson      1
# 492              mayor robert garcia      1
# 493           luz chaparro hernandez      1
# 494                  fred guttenberg      1
# 495                         amy ford      1
# 496       major general frank vavala      1
# 497           sister simone campbell      1
# 498              senator chris coons      1
# 499             keisha lance bottoms      1
# 500                     andrew young      1
# 501                  elijah cummings      1
# 502          senator elizabet warren      1
# 503           senator yvanna cancela      1
# 504                   daniel dae kim      1
# 505                   susan molinari      1
# 506               judge lina hidalgo      1
# 507                       ady barkan      1
# 508                       khizr khan      1
# 509                     donna hylton      1
# 510               senator daug jones      1
# 511                   dolores huerta      1
# 512                      jon meachin      1
# 513            governor gavin newsom      1
# 514                    amanda litman      1
# 515                   hilary clinton      1
# 516                       jim jordan      1
# 517                      nikki haley      1
# 518                  herschel walker      1
# 519                       john lewis      1
# 520                  raphael warnock      1
# 521                      jon meacham      1
# 522                          matthew      1
# 523                   barbara jordan      1
# 524                     john kennedy      1
# 525               franklin roosevelt      1
# 526                     lucy sanchez      1
# 527                          estella      1
# 528                    billie eilish      1
# 529                katherine lorenzo      1
# 530                   andrew adamski      1
# 531            alexandria villaseñor      1
# 532                              kid      1
# 533                             male      1
# 534                    justin onwenu      1
# 535           michelle lujan grisham      1
# 536                           claire      1
# 537                             kyle      1
# 538                      deb haaland      1
# 539                   gabby giffords      1
# 540                    deandra dycus      1
# 541                            debra      1
# 542                          michael      1
# 543                            garry      1
# 544                   terry williams      1
# 545                       jim bognet      1
# 546                     gavin newsom      1
# 547                   jocelyn benson      1
# 548                     alex padilla      1
# 549                              pat      1
# 550                          seymour      1
# 551                            james      1
# 552                             sara      1
# 553               kimberly guilfoyle      1
# 554                       kim klacik      1
# 555                    emily bombich      1
# 556                  franklin graham      1
# 557                     barb deburgh      1
# 558                angela cunningham      1
# 559                 alderman kennedy      1
# 560                         marjorie      1
# 561                   laura ingraham      1
# 562                    maxine waters      1
# 563                   kevin mccarthy      1
# 564                       matt gaetz      1
# 565                         michelle      1
# 566                 stacia brightmon      1
# 567                      dan scavino      1
# 568                       sean reyes      1
# 569                     debbie flood      1
# 570                       judy smith      1
# 571                     jeff weidner      1
# 572                     tim tompkins      1
# 573                       tim mahone      1
# 574                  reverend barker      1
# 575                     congregation      1
# 576                            isaac      1
# 577                      interviewer      1
# 578                       ketha otis      1
# 579                     arrion brown      1
# 580                        mike hora      1
# 581              charlotte mccracken      1
# 582                     danny groves      1
# 583                    sellers davis      1
# 584                       fawn slade      1
# 585                    jessica gavin      1
# 586                    pamela lawson      1
# 587                  rebecca vedrine      1
# 588                  manuel martinez      1
# 589                    claudia perez      1
# 590                  carmen quinones      1
# 591                      jason joyce      1
# 592                   tanya weinreis      1
# 593               rebecca friedrichs      1
# 594                     charlie kirk      1
# 595                    tiffany trump      1
# 596                       eric trump      1
# 597                      mike pompeo      1
# 598                    melania trump      1
# 599                      trevor noah      1
# 600                     abby johnson      1
# 601               bob vlaisavljevich      1
# 602              cissie graham lynch      1
# 603                    john peterson      1
# 604                     larry kudlow      1
# 605                    chris pearson      1
# 606                   richard blakey      1
# 607                        ann dorin      1
# 608                     jamie ponder      1
# 609                   richard beasly      1
# 610                       jon ponder      1
# 611                      jack brewer      1
# 612                       lara trump      1
# 613                  chen guangcheng      1
# 614                   michael mchale      1
# 615                sister dede byrne      1
# 616                       tera myers      1
# 617                    keith kellogg      1
# 618                 marsha blackburn      1
# 619                      kristi noem      1
# 620                       tom cotton      1
# 621                     ivanka trump      1
# 622                     abby phillip      1

# %%
# Función extraer para text

# Definimos un patrón RegEx para extraer los nombres de oradores que aparecen en el texto, justo antes del formato “: (mm:ss)” (ej. Donald Trump: (01:25))
# extraer nombres después de un salto de línea y antes de ": (mm:ss)"
patron = re.compile(
    r'(?<=\n)'  # Asegura que el patrón esté precedido por un salto de línea
    r'([A-ZÁÉÍÓÚÑ][\wáéíóúñ]+(?:\s+[A-ZÁÉÍÓÚÑ][\wáéíóúñ]+)*)'  # Captura nombres propios
    r'(?=\s*:\s*\(\d{1,2}:\d{2}\))'  # Lookahead para ": (mm:ss)"
)

# Aplica el patrón y devuelve una lista con todos los nombres detectados en el texto (si es str).
def extraer_oradores(texto):
    return patron.findall(texto) if isinstance(texto, str) else []

# %%
# Aplicamos la función a la columna 'text' del DataFrame. Para cada fila, obtenemos una lista de oradores, y luego la convertimos a un DataFrame.
DS_orador_from_text = pd.DataFrame(
    df_speeches['text'].apply(extraer_oradores).tolist(),
    index=df_speeches.index
).applymap(lambda x: x.lower().strip() if isinstance(x, str) else x)
# Out:
# C:\Users\karin\AppData\Local\Temp\ipykernel_24152\2220392447.py:5: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ).applymap(lambda x: x.lower().strip() if isinstance(x, str) else x)

# %%
#### Generar listado completo de oradores para identificar los distintos nombres que hacen referencia a una misma persona,
# y luego incorporar esas reglas a la función normalize_names para su estandarización.

# Aplanar listas completas (sin filtro por cantidad)
oradores_text = list(chain.from_iterable(DS_orador_from_text.values.tolist()))
conteo_text = Counter([o for o in oradores_text if isinstance(o, str)])

oradores_speaker = list(chain.from_iterable(DS_orador_from_speaker.values.tolist()))
conteo_speaker = Counter([o for o in oradores_speaker if isinstance(o, str)])

# Unir ambos conteos
conteo_total = conteo_text + conteo_speaker  # suma de Counter

# Crear DataFrame ordenado por frecuencia
df_oradores_totales = (
    pd.DataFrame(conteo_total.items(), columns=["orador", "cantidad_discursos"])
    .sort_values(by="cantidad_discursos", ascending=False)
    .reset_index(drop=True)
)

# %%
# 1) Definimos normalize_names
# Función para unificar diferentes formas de nombrar a los oradores más frecuentes en los discursos, 
# facilitando el análisis de frecuencia (Ej. “President Trump”, “Trump”, y “Donald Trump” se cuenten como un único “donald trump”).

def normalize_names(text):
    if not isinstance(text, str):
        return text

    text = text.lower().strip()  # Pasar a minúsculas y limpiar espacios
    
    # Regla: Eliminar ruido
    if text.lower().strip() in {
        'crowd', 'audience', 'multiple speakers', 'democratic candidates',
        'intro', 'announcer', 'group', 'moderator', 'reporters',
        'audience members', 'commercial', 'voice over', 'male', 'female',
        'congregation', 'interviewer'
    }:
        return None

    # Biden
    text = re.sub(r'\bvice president joe biden\b', 'joe biden', text, flags=re.IGNORECASE)
    text = re.sub(r'\bvice president biden\b', 'joe biden', text, flags=re.IGNORECASE)
    text = re.sub(r'(?<!\bjoe\s)\bbiden\b', 'joe biden', text, flags=re.IGNORECASE)

    # Trump (orden correcto: primero las formas más específicas)
    text = re.sub(r'\bpresident\s+donald\s+j\.?\s*trump\b', 'donald trump', text, flags=re.IGNORECASE)
    text = re.sub(r'\bdonald\s+j\.?\s*trump\b', 'donald trump', text, flags=re.IGNORECASE)
    text = re.sub(r'\bpresident\s+donald\s+trump\b', 'donald trump', text, flags=re.IGNORECASE)
    text = re.sub(r'\bpresident\s+trump\b', 'donald trump', text, flags=re.IGNORECASE)
    text = re.sub(r'(?<!\bdonald\s)\btrump\b(?!\s+jr\b)', 'donald trump', text, flags=re.IGNORECASE)


    # Kamala Harris
    text = re.sub(r'\bsenator kamala harris\b', 'kamala harris', text, flags=re.IGNORECASE)

    # Mike Pence
    text = re.sub(r'\bvice president mike pence\b', 'mike pence', text, flags=re.IGNORECASE)

    # Amy Klobuchar
    text = re.sub(r'\bsenator amy klobuchar\b', 'amy klobuchar', text, flags=re.IGNORECASE)

    # Elizabeth Warren
    text = re.sub(r'\bsenator elizabeth warren\b', 'elizabeth warren', text, flags=re.IGNORECASE)
    text = re.sub(r'\bwarren\b', 'elizabeth warren', text, flags=re.IGNORECASE)

    # Barack Obama
    text = re.sub(r'\bpresident barack obama\b', 'barack obama', text, flags=re.IGNORECASE)

    # Bill Clinton
    text = re.sub(r'\bpresident bill clinton\b', 'bill clinton', text, flags=re.IGNORECASE)

    # Hillary Clinton
    text = re.sub(r'\bhilary clinton\b', 'hillary clinton', text, flags=re.IGNORECASE)

    return text

# 2) Crear DataFrames limpios
DS_orador_from_speaker_clean = DS_orador_from_speaker.copy()
DS_orador_from_text_clean    = DS_orador_from_text.copy()

# 3) Aplicar normalize_names


DS_orador_from_speaker_clean = DS_orador_from_speaker_clean.map(
    lambda x: normalize_names(x) if isinstance(x, str) else x,
    na_action='ignore'
)
DS_orador_from_text_clean = DS_orador_from_text_clean.map(
    lambda x: normalize_names(x) if isinstance(x, str) else x,
    na_action='ignore'
)

# %%
# 1) Aplicar Series.unique() a cada fila para quedarnos solo con los valores únicos
DS_orador_from_text_clean = DS_orador_from_text_clean.apply(
    lambda row: pd.Series(row.dropna().unique()),  # dropna() quita NaN antes de unique()
    axis=1
)

# 2) Renombrar las columnas resultantes de forma genérica
DS_orador_from_text_clean.columns = [f'orador_{i+1}' for i in range(DS_orador_from_text_clean.shape[1])]

# 3) Rellenar con NaN las celdas faltantes si quieres asegurar un DataFrame rectangular
DS_orador_from_text_clean = DS_orador_from_text_clean.reindex(
    columns=DS_orador_from_text_clean.columns, 
    fill_value=pd.NA
)

# Mostrar resultado
# print("DS_orador_from_speaker_clean:")
# print(DS_orador_from_speaker_clean.to_string(index=False))
# print("\nDS_orador_from_text_clean:")
# print(DS_orador_from_text_clean.to_string(index=False))

# %%
# BUSCO DISCREPANCIAS ENTRE MATRICES LIMPIAS 

# 1) Inicializar lista para registros de discrepancias
rows = []

# 2) Recorrer cada fila por índice
for idx in DS_orador_from_speaker_clean.index:
    # a) Oradores esperados en la fila idx (sin NaN, ya normalizados)
    expected = [
        v for v in DS_orador_from_speaker_clean.loc[idx].tolist()
        if isinstance(v, str) and v != ''
    ]
    # b) Oradores detectados en text_clean para la misma fila
    detected = [
        v for v in DS_orador_from_text_clean.loc[idx].tolist()
        if isinstance(v, str) and v != ''
    ]
    # c) Identificar cuáles esperados NO aparecen en detected
    missing = [s for s in expected if s not in detected]
    # d) Si hay faltantes, agregar un registro: [fila, missing1, missing2, ...]
    if missing:
        rows.append([idx] + missing)

# 3) Construir el DataFrame final con la nomenclatura “_clean”
#    La primera columna es 'row_index', las siguientes son missing_1, missing_2, …
max_missing = max((len(r) - 1 for r in rows), default=0)
DF_speaker_vs_text_clean = pd.DataFrame(
    rows,
    columns=['row_index'] + [f'missing_{i+1}' for i in range(max_missing)]
)

# 4) Mostrar el resultado
# print("DF_speaker_vs_text_clean")
# print(DF_speaker_vs_text_clean)

# %%
# RELLENO CELDAS que son iguales a “democratic candidates”, “republican candidates”, “multiple speakers”, “???”  o que sean celdas vacías 
# por las columnas correspondientes a dicha fila i de la data frame DF_orador_from_text
# Partimos de los DataFrames originales: DS_orador_from_speaker y DS_orador_from_text

# Definimos las “keywords” que deben disparar el reemplazo
keywords = {
    'democratic candidates',
    'republican candidates',
    'multiple speakers',
    '???',
    'none',    # en minúsculas, para coincidir con .lower()
    ''         # cadena vacía
}

rows = []
max_len = 0

# 1) Iteramos sobre cada fila de DS_orador_from_speaker_clean
for idx, row in DS_orador_from_speaker_clean.iterrows():
    # Convertir todos los valores de la fila a cadenas minúsculas
    cells = [str(v).lower().strip() if pd.notna(v) else '' for v in row.tolist()]
    
    # 2) Determinar si hay alguna keyword en la fila original
    if any(cell in keywords for cell in cells):
        # Tomar **toda** la fila de DS_orador_from_text_clean
        values = DS_orador_from_text_clean.loc[idx].dropna().tolist()
    else:
        # Tomar **toda** la fila de DS_orador_from_speaker_clean
        values = row.dropna().tolist()
    
    rows.append(values)
    max_len = max(max_len, len(values))

# 3) Rellenar con pd.NA para que todas las filas tengan longitud max_len
records = [r + [pd.NA] * (max_len - len(r)) for r in rows]

# 4) Construir el DataFrame final con el mismo índice
DF_speaker_mas_text = pd.DataFrame(
    records,
    index=DS_orador_from_speaker_clean.index
)

# 5) Asignar nombres genéricos de columna
DF_speaker_mas_text.columns = [f'col{i+1}' for i in range(max_len)]

# Mostrar resultado
print("DF_speaker_mas_text")
print(DF_speaker_mas_text.to_string())
# Out:
# DF_speaker_mas_text
#                            col1                             col2                        col3                    col4                        col5                        col6                      col7                       col8                            col9                    col10                           col11                    col12                   col13                col14               col15              col16                   col17            col18               col19          col20            col21           col22                   col23          col24           col25                              col26           col27         col28          col29             col30           col31                col32                   col33            col34            col35          col36           col37                       col38                   col39                col40                 col41         col42            col43       col44          col45            col46             col47             col48            col49         col50         col51      col52     col53            col54         col55                 col56           col57
# 0                  david perdue                             <NA>                        <NA>                    <NA>                        <NA>                        <NA>                      <NA>                       <NA>                            <NA>                     <NA>                            <NA>                     <NA>                    <NA>                 <NA>                <NA>               <NA>                    <NA>             <NA>                <NA>           <NA>             <NA>            <NA>                    <NA>           <NA>            <NA>                               <NA>            <NA>          <NA>           <NA>              <NA>            <NA>                 <NA>                    <NA>             <NA>             <NA>           <NA>            <NA>                        <NA>                    <NA>                 <NA>                  <NA>          <NA>             <NA>        <NA>           <NA>             <NA>              <NA>              <NA>             <NA>          <NA>          <NA>       <NA>      <NA>             <NA>          <NA>                  <NA>            <NA>
# 1                     joe biden                             <NA>                        <NA>                    <NA>                        <NA>                        <NA>                      <NA>                       <NA>                            <NA>                     <NA>                            <NA>                     <NA>                    <NA>                 <NA>                <NA>               <NA>                    <NA>             <NA>                <NA>           <NA>             <NA>            <NA>                    <NA>           <NA>            <NA>                               <NA>            <NA>          <NA>           <NA>              <NA>            <NA>                 <NA>                    <NA>             <NA>             <NA>           <NA>            <NA>                        <NA>                    <NA>                 <NA>                  <NA>          <NA>             <NA>        <NA>           <NA>             <NA>              <NA>              <NA>             <NA>          <NA>          <NA>       <NA>      <NA>             <NA>          <NA>                  <NA>            <NA>
# 2                  donald trump                            seema                ron desantis                    <NA>                        <NA>                        <NA>                      <NA>                       <NA>                            <NA>                     <NA>                            <NA>                     <NA>                    <NA>                 <NA>                <NA>               <NA>                    <NA>             <NA>                <NA>           <NA>             <NA>            <NA>                    <NA>           <NA>            <NA>                               <NA>            <NA>          <NA>           <NA>              <NA>            <NA>                 <NA>                    <NA>             <NA>             <NA>           <NA>            <NA>                        <NA>                    <NA>                 <NA>                  <NA>          <NA>             <NA>        <NA>           <NA>             <NA>              <NA>              <NA>             <NA>          <NA>          <NA>       <NA>      <NA>             <NA>          <NA>                  <NA>            <NA>
# 3                     joe biden            george stephanopoulos                nicholas fed               kelly lee              anthony archer             cedric humphrey     george stephanopoulus         angelia politarhos                   nathan osburn             andrew lewis                            <NA>                     <NA>                    <NA>                 <NA>                <NA>               <NA>                    <NA>             <NA>                <NA>           <NA>             <NA>            <NA>                    <NA>           <NA>            <NA>                               <NA>            <NA>          <NA>           <NA>              <NA>            <NA>                 <NA>                    <NA>             <NA>             <NA>           <NA>            <NA>                        <NA>                    <NA>                 <NA>                  <NA>          <NA>             <NA>        <NA>           <NA>             <NA>              <NA>              <NA>             <NA>          <NA>          <NA>       <NA>      <NA>             <NA>          <NA>                  <NA>            <NA>
# 4              savannah guthrie                     donald trump             jacqueline lugo            barbara peña               isabella peña                    savannah  cristy montesinos alonso              adam schucher                    moriah geene              cindy velez                   paulette dale                     <NA>                    <NA>                 <NA>                <NA>               <NA>                    <NA>             <NA>                <NA>           <NA>             <NA>            <NA>                    <NA>           <NA>            <NA>                               <NA>            <NA>          <NA>           <NA>              <NA>            <NA>                 <NA>                    <NA>             <NA>             <NA>           <NA>            <NA>                        <NA>                    <NA>                 <NA>                  <NA>          <NA>             <NA>        <NA>           <NA>             <NA>              <NA>              <NA>             <NA>          <NA>          <NA>       <NA>      <NA>             <NA>          <NA>                  <NA>            <NA>
# 5                  donald trump                     david rouzer                        <NA>                    <NA>                        <NA>                        <NA>                      <NA>                       <NA>                            <NA>                     <NA>                            <NA>                     <NA>                    <NA>                 <NA>                <NA>               <NA>                    <NA>             <NA>                <NA>           <NA>             <NA>            <NA>                    <NA>           <NA>            <NA>                               <NA>            <NA>          <NA>           <NA>              <NA>            <NA>                 <NA>                    <NA>             <NA>             <NA>           <NA>            <NA>                        <NA>                    <NA>                 <NA>                  <NA>          <NA>             <NA>        <NA>           <NA>             <NA>              <NA>              <NA>             <NA>          <NA>          <NA>       <NA>      <NA>             <NA>          <NA>                  <NA>            <NA>
# 6             pedro fuentes cid                       mike pence                        <NA>                    <NA>                        <NA>                        <NA>                      <NA>                       <NA>                            <NA>                     <NA>                            <NA>                     <NA>                    <NA>                 <NA>                <NA>               <NA>                    <NA>             <NA>                <NA>           <NA>             <NA>            <NA>                    <NA>           <NA>            <NA>                               <NA>            <NA>          <NA>           <NA>              <NA>            <NA>                 <NA>                    <NA>             <NA>             <NA>           <NA>            <NA>                        <NA>                    <NA>                 <NA>                  <NA>          <NA>             <NA>        <NA>           <NA>             <NA>              <NA>              <NA>             <NA>          <NA>          <NA>       <NA>      <NA>             <NA>          <NA>                  <NA>            <NA>
# 7                          <NA>                             <NA>                        <NA>                    <NA>                        <NA>                        <NA>                      <NA>                       <NA>                            <NA>                     <NA>                            <NA>                     <NA>                    <NA>                 <NA>                <NA>               <NA>                    <NA>             <NA>                <NA>           <NA>             <NA>            <NA>                    <NA>           <NA>            <NA>                               <NA>            <NA>          <NA>           <NA>              <NA>            <NA>                 <NA>                    <NA>             <NA>             <NA>           <NA>            <NA>                        <NA>                    <NA>                 <NA>                  <NA>          <NA>             <NA>        <NA>           <NA>             <NA>              <NA>              <NA>             <NA>          <NA>          <NA>       <NA>      <NA>             <NA>          <NA>                  <NA>            <NA>
# 8                    mike pence                             <NA>                        <NA>                    <NA>                        <NA>                        <NA>                      <NA>                       <NA>                            <NA>                     <NA>                            <NA>                     <NA>                    <NA>                 <NA>                <NA>               <NA>                    <NA>             <NA>                <NA>           <NA>             <NA>            <NA>                    <NA>           <NA>            <NA>                               <NA>            <NA>          <NA>           <NA>              <NA>            <NA>                 <NA>                    <NA>             <NA>             <NA>           <NA>            <NA>                        <NA>                    <NA>                 <NA>                  <NA>          <NA>             <NA>        <NA>           <NA>             <NA>              <NA>              <NA>             <NA>          <NA>          <NA>       <NA>      <NA>             <NA>          <NA>                  <NA>            <NA>
# 9               damian ferguson                        joe biden                        <NA>                    <NA>                        <NA>                        <NA>                      <NA>                       <NA>                            <NA>                     <NA>                            <NA>                     <NA>                    <NA>                 <NA>                <NA>               <NA>                    <NA>             <NA>                <NA>           <NA>             <NA>            <NA>                    <NA>           <NA>            <NA>                               <NA>            <NA>          <NA>           <NA>              <NA>            <NA>                 <NA>                    <NA>             <NA>             <NA>           <NA>            <NA>                        <NA>                    <NA>                 <NA>                  <NA>          <NA>             <NA>        <NA>           <NA>             <NA>              <NA>              <NA>             <NA>          <NA>          <NA>       <NA>      <NA>             <NA>          <NA>                  <NA>            <NA>
# 10                 donald trump                             <NA>                        <NA>                    <NA>                        <NA>                        <NA>                      <NA>                       <NA>                            <NA>                     <NA>                            <NA>                     <NA>                    <NA>                 <NA>                <NA>               <NA>                    <NA>             <NA>                <NA>           <NA>             <NA>            <NA>                    <NA>           <NA>            <NA>                               <NA>            <NA>          <NA>           <NA>              <NA>            <NA>                 <NA>                    <NA>             <NA>             <NA>           <NA>            <NA>                        <NA>                    <NA>                 <NA>                  <NA>          <NA>             <NA>        <NA>           <NA>             <NA>              <NA>              <NA>             <NA>          <NA>          <NA>       <NA>      <NA>             <NA>          <NA>                  <NA>            <NA>
# 11                   toby feuer                        joe biden                        <NA>                    <NA>                        <NA>                        <NA>                      <NA>                       <NA>                            <NA>                     <NA>                            <NA>                     <NA>                    <NA>                 <NA>                <NA>               <NA>                    <NA>             <NA>                <NA>           <NA>             <NA>            <NA>                    <NA>           <NA>            <NA>                               <NA>            <NA>          <NA>           <NA>              <NA>            <NA>                 <NA>                    <NA>             <NA>             <NA>           <NA>            <NA>                        <NA>                    <NA>                 <NA>                  <NA>          <NA>             <NA>        <NA>           <NA>             <NA>              <NA>              <NA>             <NA>          <NA>          <NA>       <NA>      <NA>             <NA>          <NA>                  <NA>            <NA>
# 12                   mike pence                             <NA>                        <NA>                    <NA>                        <NA>                        <NA>                      <NA>                       <NA>                            <NA>                     <NA>                            <NA>                     <NA>                    <NA>                 <NA>                <NA>               <NA>                    <NA>             <NA>                <NA>           <NA>             <NA>            <NA>                    <NA>           <NA>            <NA>                               <NA>            <NA>          <NA>           <NA>              <NA>            <NA>                 <NA>                    <NA>             <NA>             <NA>           <NA>            <NA>                        <NA>                    <NA>                 <NA>                  <NA>          <NA>             <NA>        <NA>           <NA>             <NA>              <NA>              <NA>             <NA>          <NA>          <NA>       <NA>      <NA>             <NA>          <NA>                  <NA>            <NA>
# 13                 donald trump                             <NA>                        <NA>                    <NA>                        <NA>                        <NA>                      <NA>                       <NA>                            <NA>                     <NA>                            <NA>                     <NA>                    <NA>                 <NA>                <NA>               <NA>                    <NA>             <NA>                <NA>           <NA>             <NA>            <NA>                    <NA>           <NA>            <NA>                               <NA>            <NA>          <NA>           <NA>              <NA>            <NA>                 <NA>                    <NA>             <NA>             <NA>           <NA>            <NA>                        <NA>                    <NA>                 <NA>                  <NA>          <NA>             <NA>        <NA>           <NA>             <NA>              <NA>              <NA>             <NA>          <NA>          <NA>       <NA>      <NA>             <NA>          <NA>                  <NA>            <NA>
# 14                    joe biden                             <NA>                        <NA>                    <NA>                        <NA>                        <NA>                      <NA>                       <NA>                            <NA>                     <NA>                            <NA>                     <NA>                    <NA>                 <NA>                <NA>               <NA>                    <NA>             <NA>                <NA>           <NA>             <NA>            <NA>                    <NA>           <NA>            <NA>                               <NA>            <NA>          <NA>           <NA>              <NA>            <NA>                 <NA>                    <NA>             <NA>             <NA>           <NA>            <NA>                        <NA>                    <NA>                 <NA>                  <NA>          <NA>             <NA>        <NA>           <NA>             <NA>              <NA>              <NA>             <NA>          <NA>          <NA>       <NA>      <NA>             <NA>          <NA>                  <NA>            <NA>
# 15                    joe biden                             <NA>                        <NA>                    <NA>                        <NA>                        <NA>                      <NA>                       <NA>                            <NA>                     <NA>                            <NA>                     <NA>                    <NA>                 <NA>                <NA>               <NA>                    <NA>             <NA>                <NA>           <NA>             <NA>            <NA>                    <NA>           <NA>            <NA>                               <NA>            <NA>          <NA>           <NA>              <NA>            <NA>                 <NA>                    <NA>             <NA>             <NA>           <NA>            <NA>                        <NA>                    <NA>                 <NA>                  <NA>          <NA>             <NA>        <NA>           <NA>             <NA>              <NA>              <NA>             <NA>          <NA>          <NA>       <NA>      <NA>             <NA>          <NA>                  <NA>            <NA>
# 16                   mike pence                             <NA>                        <NA>                    <NA>                        <NA>                        <NA>                      <NA>                       <NA>                            <NA>                     <NA>                            <NA>                     <NA>                    <NA>                 <NA>                <NA>               <NA>                    <NA>             <NA>                <NA>           <NA>             <NA>            <NA>                    <NA>           <NA>            <NA>                               <NA>            <NA>          <NA>           <NA>              <NA>            <NA>                 <NA>                    <NA>             <NA>             <NA>           <NA>            <NA>                        <NA>                    <NA>                 <NA>                  <NA>          <NA>             <NA>        <NA>           <NA>             <NA>              <NA>              <NA>             <NA>          <NA>          <NA>       <NA>      <NA>             <NA>          <NA>                  <NA>            <NA>
# 17                    joe biden                             <NA>                        <NA>                    <NA>                        <NA>                        <NA>                      <NA>                       <NA>                            <NA>                     <NA>                            <NA>                     <NA>                    <NA>                 <NA>                <NA>               <NA>                    <NA>             <NA>                <NA>           <NA>             <NA>            <NA>                    <NA>           <NA>            <NA>                               <NA>            <NA>          <NA>           <NA>              <NA>            <NA>                 <NA>                    <NA>             <NA>             <NA>           <NA>            <NA>                        <NA>                    <NA>                 <NA>                  <NA>          <NA>             <NA>        <NA>           <NA>             <NA>              <NA>              <NA>             <NA>          <NA>          <NA>       <NA>      <NA>             <NA>          <NA>                  <NA>            <NA>
# 18                    joe biden                             <NA>                        <NA>                    <NA>                        <NA>                        <NA>                      <NA>                       <NA>                            <NA>                     <NA>                            <NA>                     <NA>                    <NA>                 <NA>                <NA>               <NA>                    <NA>             <NA>                <NA>           <NA>             <NA>            <NA>                    <NA>           <NA>            <NA>                               <NA>            <NA>          <NA>           <NA>              <NA>            <NA>                 <NA>                    <NA>             <NA>             <NA>           <NA>            <NA>                        <NA>                    <NA>                 <NA>                  <NA>          <NA>             <NA>        <NA>           <NA>             <NA>              <NA>              <NA>             <NA>          <NA>          <NA>       <NA>      <NA>             <NA>          <NA>                  <NA>            <NA>
# 19                 donald trump                             <NA>                        <NA>                    <NA>                        <NA>                        <NA>                      <NA>                       <NA>                            <NA>                     <NA>                            <NA>                     <NA>                    <NA>                 <NA>                <NA>               <NA>                    <NA>             <NA>                <NA>           <NA>             <NA>            <NA>                    <NA>           <NA>            <NA>                               <NA>            <NA>          <NA>           <NA>              <NA>            <NA>                 <NA>                    <NA>             <NA>             <NA>           <NA>            <NA>                        <NA>                    <NA>                 <NA>                  <NA>          <NA>             <NA>        <NA>           <NA>             <NA>              <NA>              <NA>             <NA>          <NA>          <NA>       <NA>      <NA>             <NA>          <NA>                  <NA>            <NA>
# 20               lindsey graham                   jamie harrison                    amy wood             gordon dill              carolyn murray                louis yuhasz                      <NA>                       <NA>                            <NA>                     <NA>                            <NA>                     <NA>                    <NA>                 <NA>                <NA>               <NA>                    <NA>             <NA>                <NA>           <NA>             <NA>            <NA>                    <NA>           <NA>            <NA>                               <NA>            <NA>          <NA>           <NA>              <NA>            <NA>                 <NA>                    <NA>             <NA>             <NA>           <NA>            <NA>                        <NA>                    <NA>                 <NA>                  <NA>          <NA>             <NA>        <NA>           <NA>             <NA>              <NA>              <NA>             <NA>          <NA>          <NA>       <NA>      <NA>             <NA>          <NA>                  <NA>            <NA>
# 21                    joe biden                             <NA>                        <NA>                    <NA>                        <NA>                        <NA>                      <NA>                       <NA>                            <NA>                     <NA>                            <NA>                     <NA>                    <NA>                 <NA>                <NA>               <NA>                    <NA>             <NA>                <NA>           <NA>             <NA>            <NA>                    <NA>           <NA>            <NA>                               <NA>            <NA>          <NA>           <NA>              <NA>            <NA>                 <NA>                    <NA>             <NA>             <NA>           <NA>            <NA>                        <NA>                    <NA>                 <NA>                  <NA>          <NA>             <NA>        <NA>           <NA>             <NA>              <NA>              <NA>             <NA>          <NA>          <NA>       <NA>      <NA>             <NA>          <NA>                  <NA>            <NA>
# 22                 donald trump                     sean hannity                        <NA>                    <NA>                        <NA>                        <NA>                      <NA>                       <NA>                            <NA>                     <NA>                            <NA>                     <NA>                    <NA>                 <NA>                <NA>               <NA>                    <NA>             <NA>                <NA>           <NA>             <NA>            <NA>                    <NA>           <NA>            <NA>                               <NA>            <NA>          <NA>           <NA>              <NA>            <NA>                 <NA>                    <NA>             <NA>             <NA>           <NA>            <NA>                        <NA>                    <NA>                 <NA>                  <NA>          <NA>             <NA>        <NA>           <NA>             <NA>              <NA>              <NA>             <NA>          <NA>          <NA>       <NA>      <NA>             <NA>          <NA>                  <NA>            <NA>
# 23                kamala harris                        joe biden                        <NA>                    <NA>                        <NA>                        <NA>                      <NA>                       <NA>                            <NA>                     <NA>                            <NA>                     <NA>                    <NA>                 <NA>                <NA>               <NA>                    <NA>             <NA>                <NA>           <NA>             <NA>            <NA>                    <NA>           <NA>            <NA>                               <NA>            <NA>          <NA>           <NA>              <NA>            <NA>                 <NA>                    <NA>             <NA>             <NA>           <NA>            <NA>                        <NA>                    <NA>                 <NA>                  <NA>          <NA>             <NA>        <NA>           <NA>             <NA>              <NA>              <NA>             <NA>          <NA>          <NA>       <NA>      <NA>             <NA>          <NA>                  <NA>            <NA>
# 24                   mike pence                             <NA>                        <NA>                    <NA>                        <NA>                        <NA>                      <NA>                       <NA>                            <NA>                     <NA>                            <NA>                     <NA>                    <NA>                 <NA>                <NA>               <NA>                    <NA>             <NA>                <NA>           <NA>             <NA>            <NA>                    <NA>           <NA>            <NA>                               <NA>            <NA>          <NA>           <NA>              <NA>            <NA>                 <NA>                    <NA>             <NA>             <NA>           <NA>            <NA>                        <NA>                    <NA>                 <NA>                  <NA>          <NA>             <NA>        <NA>           <NA>             <NA>              <NA>              <NA>             <NA>          <NA>          <NA>       <NA>      <NA>             <NA>          <NA>                  <NA>            <NA>
# 25                        maria                     donald trump                        <NA>                    <NA>                        <NA>                        <NA>                      <NA>                       <NA>                            <NA>                     <NA>                            <NA>                     <NA>                    <NA>                 <NA>                <NA>               <NA>                    <NA>             <NA>                <NA>           <NA>             <NA>            <NA>                    <NA>           <NA>            <NA>                               <NA>            <NA>          <NA>           <NA>              <NA>            <NA>                 <NA>                    <NA>             <NA>             <NA>           <NA>            <NA>                        <NA>                    <NA>                 <NA>                  <NA>          <NA>             <NA>        <NA>           <NA>             <NA>              <NA>              <NA>             <NA>          <NA>          <NA>       <NA>      <NA>             <NA>          <NA>                  <NA>            <NA>
# 26                   susan page                    kamala harris                  mike pence                    <NA>                        <NA>                        <NA>                      <NA>                       <NA>                            <NA>                     <NA>                            <NA>                     <NA>                    <NA>                 <NA>                <NA>               <NA>                    <NA>             <NA>                <NA>           <NA>             <NA>            <NA>                    <NA>           <NA>            <NA>                               <NA>            <NA>          <NA>           <NA>              <NA>            <NA>                 <NA>                    <NA>             <NA>             <NA>           <NA>            <NA>                        <NA>                    <NA>                 <NA>                  <NA>          <NA>             <NA>        <NA>           <NA>             <NA>              <NA>              <NA>             <NA>          <NA>          <NA>       <NA>      <NA>             <NA>          <NA>                  <NA>            <NA>
# 27                    joe biden                             <NA>                        <NA>                    <NA>                        <NA>                        <NA>                      <NA>                       <NA>                            <NA>                     <NA>                            <NA>                     <NA>                    <NA>                 <NA>                <NA>               <NA>                    <NA>             <NA>                <NA>           <NA>             <NA>            <NA>                    <NA>           <NA>            <NA>                               <NA>            <NA>          <NA>           <NA>              <NA>            <NA>                 <NA>                    <NA>             <NA>             <NA>           <NA>            <NA>                        <NA>                    <NA>                 <NA>                  <NA>          <NA>             <NA>        <NA>           <NA>             <NA>              <NA>              <NA>             <NA>          <NA>          <NA>       <NA>      <NA>             <NA>          <NA>                  <NA>            <NA>
# 28               michelle obama                             <NA>                        <NA>                    <NA>                        <NA>                        <NA>                      <NA>                       <NA>                            <NA>                     <NA>                            <NA>                     <NA>                    <NA>                 <NA>                <NA>               <NA>                    <NA>             <NA>                <NA>           <NA>             <NA>            <NA>                    <NA>           <NA>            <NA>                               <NA>            <NA>          <NA>           <NA>              <NA>            <NA>                 <NA>                    <NA>             <NA>             <NA>           <NA>            <NA>                        <NA>                    <NA>                 <NA>                  <NA>          <NA>             <NA>        <NA>           <NA>             <NA>              <NA>              <NA>             <NA>          <NA>          <NA>       <NA>      <NA>             <NA>          <NA>                  <NA>            <NA>
# 29                  lester holt                   hallie jackson                   joe biden         vanessa tamariz                    jonathan                 brian smith               chris hayes           savannah guthrie                 nicolle wallace    michelle cruz marrero                   nicole maddox                hota kotb         danny lavendera       ismael illiano      peter gonzalez               <NA>                    <NA>             <NA>                <NA>           <NA>             <NA>            <NA>                    <NA>           <NA>            <NA>                               <NA>            <NA>          <NA>           <NA>              <NA>            <NA>                 <NA>                    <NA>             <NA>             <NA>           <NA>            <NA>                        <NA>                    <NA>                 <NA>                  <NA>          <NA>             <NA>        <NA>           <NA>             <NA>              <NA>              <NA>             <NA>          <NA>          <NA>       <NA>      <NA>             <NA>          <NA>                  <NA>            <NA>
# 30                    joe biden                             <NA>                        <NA>                    <NA>                        <NA>                        <NA>                      <NA>                       <NA>                            <NA>                     <NA>                            <NA>                     <NA>                    <NA>                 <NA>                <NA>               <NA>                    <NA>             <NA>                <NA>           <NA>             <NA>            <NA>                    <NA>           <NA>            <NA>                               <NA>            <NA>          <NA>           <NA>              <NA>            <NA>                 <NA>                    <NA>             <NA>             <NA>           <NA>            <NA>                        <NA>                    <NA>                 <NA>                  <NA>          <NA>             <NA>        <NA>           <NA>             <NA>              <NA>              <NA>             <NA>          <NA>          <NA>       <NA>      <NA>             <NA>          <NA>                  <NA>            <NA>
# 31               bernie sanders                             <NA>                        <NA>                    <NA>                        <NA>                        <NA>                      <NA>                       <NA>                            <NA>                     <NA>                            <NA>                     <NA>                    <NA>                 <NA>                <NA>               <NA>                    <NA>             <NA>                <NA>           <NA>             <NA>            <NA>                    <NA>           <NA>            <NA>                               <NA>            <NA>          <NA>           <NA>              <NA>            <NA>                 <NA>                    <NA>             <NA>             <NA>           <NA>            <NA>                        <NA>                    <NA>                 <NA>                  <NA>          <NA>             <NA>        <NA>           <NA>             <NA>              <NA>              <NA>             <NA>          <NA>          <NA>       <NA>      <NA>             <NA>          <NA>                  <NA>            <NA>
# 32               jaime harrison                   lindsey graham                 bill sharpe              joe bustos               eric weisfeld                  mike cihla            richard rogers              alonzo julian                     adam mencer                     <NA>                            <NA>                     <NA>                    <NA>                 <NA>                <NA>               <NA>                    <NA>             <NA>                <NA>           <NA>             <NA>            <NA>                    <NA>           <NA>            <NA>                               <NA>            <NA>          <NA>           <NA>              <NA>            <NA>                 <NA>                    <NA>             <NA>             <NA>           <NA>            <NA>                        <NA>                    <NA>                 <NA>                  <NA>          <NA>             <NA>        <NA>           <NA>             <NA>              <NA>              <NA>             <NA>          <NA>          <NA>       <NA>      <NA>             <NA>          <NA>                  <NA>            <NA>
# 33               bernie sanders                             <NA>                        <NA>                    <NA>                        <NA>                        <NA>                      <NA>                       <NA>                            <NA>                     <NA>                            <NA>                     <NA>                    <NA>                 <NA>                <NA>               <NA>                    <NA>             <NA>                <NA>           <NA>             <NA>            <NA>                    <NA>           <NA>            <NA>                               <NA>            <NA>          <NA>           <NA>              <NA>            <NA>                 <NA>                    <NA>             <NA>             <NA>           <NA>            <NA>                        <NA>                    <NA>                 <NA>                  <NA>          <NA>             <NA>        <NA>           <NA>             <NA>              <NA>              <NA>             <NA>          <NA>          <NA>       <NA>      <NA>             <NA>          <NA>                  <NA>            <NA>
# 34                    joe biden                             john                        <NA>                    <NA>                        <NA>                        <NA>                      <NA>                       <NA>                            <NA>                     <NA>                            <NA>                     <NA>                    <NA>                 <NA>                <NA>               <NA>                    <NA>             <NA>                <NA>           <NA>             <NA>            <NA>                    <NA>           <NA>            <NA>                               <NA>            <NA>          <NA>           <NA>              <NA>            <NA>                 <NA>                    <NA>             <NA>             <NA>           <NA>            <NA>                        <NA>                    <NA>                 <NA>                  <NA>          <NA>             <NA>        <NA>           <NA>             <NA>              <NA>              <NA>             <NA>          <NA>          <NA>       <NA>      <NA>             <NA>          <NA>                  <NA>            <NA>
# 35                         <NA>                             <NA>                        <NA>                    <NA>                        <NA>                        <NA>                      <NA>                       <NA>                            <NA>                     <NA>                            <NA>                     <NA>                    <NA>                 <NA>                <NA>               <NA>                    <NA>             <NA>                <NA>           <NA>             <NA>            <NA>                    <NA>           <NA>            <NA>                               <NA>            <NA>          <NA>           <NA>              <NA>            <NA>                 <NA>                    <NA>             <NA>             <NA>           <NA>            <NA>                        <NA>                    <NA>                 <NA>                  <NA>          <NA>             <NA>        <NA>           <NA>             <NA>              <NA>              <NA>             <NA>          <NA>          <NA>       <NA>      <NA>             <NA>          <NA>                  <NA>            <NA>
# 36                   dina titus                    kamala harris               steve sisolak                    <NA>                        <NA>                        <NA>                      <NA>                       <NA>                            <NA>                     <NA>                            <NA>                     <NA>                    <NA>                 <NA>                <NA>               <NA>                    <NA>             <NA>                <NA>           <NA>             <NA>            <NA>                    <NA>           <NA>            <NA>                               <NA>            <NA>          <NA>           <NA>              <NA>            <NA>                 <NA>                    <NA>             <NA>             <NA>           <NA>            <NA>                        <NA>                    <NA>                 <NA>                  <NA>          <NA>             <NA>        <NA>           <NA>             <NA>              <NA>              <NA>             <NA>          <NA>          <NA>       <NA>      <NA>             <NA>          <NA>                  <NA>            <NA>
# 37                 matt hoffman                        joe biden                        <NA>                    <NA>                        <NA>                        <NA>                      <NA>                       <NA>                            <NA>                     <NA>                            <NA>                     <NA>                    <NA>                 <NA>                <NA>               <NA>                    <NA>             <NA>                <NA>           <NA>             <NA>            <NA>                    <NA>           <NA>            <NA>                               <NA>            <NA>          <NA>           <NA>              <NA>            <NA>                 <NA>                    <NA>             <NA>             <NA>           <NA>            <NA>                        <NA>                    <NA>                 <NA>                  <NA>          <NA>             <NA>        <NA>           <NA>             <NA>              <NA>              <NA>             <NA>          <NA>          <NA>       <NA>      <NA>             <NA>          <NA>                  <NA>            <NA>
# 38                 sean hannity                     donald trump                        <NA>                    <NA>                        <NA>                        <NA>                      <NA>                       <NA>                            <NA>                     <NA>                            <NA>                     <NA>                    <NA>                 <NA>                <NA>               <NA>                    <NA>             <NA>                <NA>           <NA>             <NA>            <NA>                    <NA>           <NA>            <NA>                               <NA>            <NA>          <NA>           <NA>              <NA>            <NA>                 <NA>                    <NA>             <NA>             <NA>           <NA>            <NA>                        <NA>                    <NA>                 <NA>                  <NA>          <NA>             <NA>        <NA>           <NA>             <NA>              <NA>              <NA>             <NA>          <NA>          <NA>       <NA>      <NA>             <NA>          <NA>                  <NA>            <NA>
# 39                   ben carson                       mike pence                        <NA>                    <NA>                        <NA>                        <NA>                      <NA>                       <NA>                            <NA>                     <NA>                            <NA>                     <NA>                    <NA>                 <NA>                <NA>               <NA>                    <NA>             <NA>                <NA>           <NA>             <NA>            <NA>                    <NA>           <NA>            <NA>                               <NA>            <NA>          <NA>           <NA>              <NA>            <NA>                 <NA>                    <NA>             <NA>             <NA>           <NA>            <NA>                        <NA>                    <NA>                 <NA>                  <NA>          <NA>             <NA>        <NA>           <NA>             <NA>              <NA>              <NA>             <NA>          <NA>          <NA>       <NA>      <NA>             <NA>          <NA>                  <NA>            <NA>
# ...
# 256                 andrew yang                             <NA>                        <NA>                    <NA>                        <NA>                        <NA>                      <NA>                       <NA>                            <NA>                     <NA>                            <NA>                     <NA>                    <NA>                 <NA>                <NA>               <NA>                    <NA>             <NA>                <NA>           <NA>             <NA>            <NA>                    <NA>           <NA>            <NA>                               <NA>            <NA>          <NA>           <NA>              <NA>            <NA>                 <NA>                    <NA>             <NA>             <NA>           <NA>            <NA>                        <NA>                    <NA>                 <NA>                  <NA>          <NA>             <NA>        <NA>           <NA>             <NA>              <NA>              <NA>             <NA>          <NA>          <NA>       <NA>      <NA>             <NA>          <NA>                  <NA>            <NA>
# 257                donald trump                             <NA>                        <NA>                    <NA>                        <NA>                        <NA>                      <NA>                       <NA>                            <NA>                     <NA>                            <NA>                     <NA>                    <NA>                 <NA>                <NA>               <NA>                    <NA>             <NA>                <NA>           <NA>             <NA>            <NA>                    <NA>           <NA>            <NA>                               <NA>            <NA>          <NA>           <NA>              <NA>            <NA>                 <NA>                    <NA>             <NA>             <NA>           <NA>            <NA>                        <NA>                    <NA>                 <NA>                  <NA>          <NA>             <NA>        <NA>           <NA>             <NA>              <NA>              <NA>             <NA>          <NA>          <NA>       <NA>      <NA>             <NA>          <NA>                  <NA>            <NA>
# 258                 andrew yang                             <NA>                        <NA>                    <NA>                        <NA>                        <NA>                      <NA>                       <NA>                            <NA>                     <NA>                            <NA>                     <NA>                    <NA>                 <NA>                <NA>               <NA>                    <NA>             <NA>                <NA>           <NA>             <NA>            <NA>                    <NA>           <NA>            <NA>                               <NA>            <NA>          <NA>           <NA>              <NA>            <NA>                 <NA>                    <NA>             <NA>             <NA>           <NA>            <NA>                        <NA>                    <NA>                 <NA>                  <NA>          <NA>             <NA>        <NA>           <NA>             <NA>              <NA>              <NA>             <NA>          <NA>          <NA>       <NA>      <NA>             <NA>          <NA>                  <NA>            <NA>
# 259  elizabeth elizabeth warren                              amy                       nancy          anders helberg                     sanders                        macy                    judith                      april                            <NA>                     <NA>                            <NA>                     <NA>                    <NA>                 <NA>                <NA>               <NA>                    <NA>             <NA>                <NA>           <NA>             <NA>            <NA>                    <NA>           <NA>            <NA>                               <NA>            <NA>          <NA>           <NA>              <NA>            <NA>                 <NA>                    <NA>             <NA>             <NA>           <NA>            <NA>                        <NA>                    <NA>                 <NA>                  <NA>          <NA>             <NA>        <NA>           <NA>             <NA>              <NA>              <NA>             <NA>          <NA>          <NA>       <NA>      <NA>             <NA>          <NA>                  <NA>            <NA>
# 260                jane sanders                   bernie sanders                        <NA>                    <NA>                        <NA>                        <NA>                      <NA>                       <NA>                            <NA>                     <NA>                            <NA>                     <NA>                    <NA>                 <NA>                <NA>               <NA>                    <NA>             <NA>                <NA>           <NA>             <NA>            <NA>                    <NA>           <NA>            <NA>                               <NA>            <NA>          <NA>           <NA>              <NA>            <NA>                 <NA>                    <NA>             <NA>             <NA>           <NA>            <NA>                        <NA>                    <NA>                 <NA>                  <NA>          <NA>             <NA>        <NA>           <NA>             <NA>              <NA>              <NA>             <NA>          <NA>          <NA>       <NA>      <NA>             <NA>          <NA>                  <NA>            <NA>
# 261              pete buttigieg             congresswoman kuster                        <NA>                    <NA>                        <NA>                        <NA>                      <NA>                       <NA>                            <NA>                     <NA>                            <NA>                     <NA>                    <NA>                 <NA>                <NA>               <NA>                    <NA>             <NA>                <NA>           <NA>             <NA>            <NA>                    <NA>           <NA>            <NA>                               <NA>            <NA>          <NA>           <NA>              <NA>            <NA>                 <NA>                    <NA>             <NA>             <NA>           <NA>            <NA>                        <NA>                    <NA>                 <NA>                  <NA>          <NA>             <NA>        <NA>           <NA>             <NA>              <NA>              <NA>             <NA>          <NA>          <NA>       <NA>      <NA>             <NA>          <NA>                  <NA>            <NA>
# 262                   joe biden                   bernie sanders               amy klobuchar              tom steyer                 andrew yang  elizabeth elizabeth warren            pete buttigieg                    lindsey                      david muir         monica hernandez                     adam sexton             linsey davis                    <NA>                 <NA>                <NA>               <NA>                    <NA>             <NA>                <NA>           <NA>             <NA>            <NA>                    <NA>           <NA>            <NA>                               <NA>            <NA>          <NA>           <NA>              <NA>            <NA>                 <NA>                    <NA>             <NA>             <NA>           <NA>            <NA>                        <NA>                    <NA>                 <NA>                  <NA>          <NA>             <NA>        <NA>           <NA>             <NA>              <NA>              <NA>             <NA>          <NA>          <NA>       <NA>      <NA>             <NA>          <NA>                  <NA>            <NA>
# 263              mike bloomberg                             <NA>                        <NA>                    <NA>                        <NA>                        <NA>                      <NA>                       <NA>                            <NA>                     <NA>                            <NA>                     <NA>                    <NA>                 <NA>                <NA>               <NA>                    <NA>             <NA>                <NA>           <NA>             <NA>            <NA>                    <NA>           <NA>            <NA>                               <NA>            <NA>          <NA>           <NA>              <NA>            <NA>                 <NA>                    <NA>             <NA>             <NA>           <NA>            <NA>                        <NA>                    <NA>                 <NA>                  <NA>          <NA>             <NA>        <NA>           <NA>             <NA>              <NA>              <NA>             <NA>          <NA>          <NA>       <NA>      <NA>             <NA>          <NA>                  <NA>            <NA>
# 264              bernie sanders                             gary                        <NA>                    <NA>                        <NA>                        <NA>                      <NA>                       <NA>                            <NA>                     <NA>                            <NA>                     <NA>                    <NA>                 <NA>                <NA>               <NA>                    <NA>             <NA>                <NA>           <NA>             <NA>            <NA>                    <NA>           <NA>            <NA>                               <NA>            <NA>          <NA>           <NA>              <NA>            <NA>                 <NA>                    <NA>             <NA>             <NA>           <NA>            <NA>                        <NA>                    <NA>                 <NA>                  <NA>          <NA>             <NA>        <NA>           <NA>             <NA>              <NA>              <NA>             <NA>          <NA>          <NA>       <NA>      <NA>             <NA>          <NA>                  <NA>            <NA>
# 265              bernie sanders       elizabeth elizabeth warren                   joe biden          pete buttigieg               amy klobuchar                 andrew yang                      <NA>                       <NA>                            <NA>                     <NA>                            <NA>                     <NA>                    <NA>                 <NA>                <NA>               <NA>                    <NA>             <NA>                <NA>           <NA>             <NA>            <NA>                    <NA>           <NA>            <NA>                               <NA>            <NA>          <NA>           <NA>              <NA>            <NA>                 <NA>                    <NA>             <NA>             <NA>           <NA>            <NA>                        <NA>                    <NA>                 <NA>                  <NA>          <NA>             <NA>        <NA>           <NA>             <NA>              <NA>              <NA>             <NA>          <NA>          <NA>       <NA>      <NA>             <NA>          <NA>                  <NA>            <NA>
# 266                donald trump                     kim reynolds               sarah sanders                    <NA>                        <NA>                        <NA>                      <NA>                       <NA>                            <NA>                     <NA>                            <NA>                     <NA>                    <NA>                 <NA>                <NA>               <NA>                    <NA>             <NA>                <NA>           <NA>             <NA>            <NA>                    <NA>           <NA>            <NA>                               <NA>            <NA>          <NA>           <NA>              <NA>            <NA>                 <NA>                    <NA>             <NA>             <NA>           <NA>            <NA>                        <NA>                    <NA>                 <NA>                  <NA>          <NA>             <NA>        <NA>           <NA>             <NA>              <NA>              <NA>             <NA>          <NA>          <NA>       <NA>      <NA>             <NA>          <NA>                  <NA>            <NA>
# 267                donald trump                    jeff van drew                        <NA>                    <NA>                        <NA>                        <NA>                      <NA>                       <NA>                            <NA>                     <NA>                            <NA>                     <NA>                    <NA>                 <NA>                <NA>               <NA>                    <NA>             <NA>                <NA>           <NA>             <NA>            <NA>                    <NA>           <NA>            <NA>                               <NA>            <NA>          <NA>           <NA>              <NA>            <NA>                 <NA>                    <NA>             <NA>             <NA>           <NA>            <NA>                        <NA>                    <NA>                 <NA>                  <NA>          <NA>             <NA>        <NA>           <NA>             <NA>              <NA>              <NA>             <NA>          <NA>          <NA>       <NA>      <NA>             <NA>          <NA>                  <NA>            <NA>
# 268              bernie sanders                     wolf blitzer                   joe biden           amy klobuchar              pete buttigieg                  tom steyer              abby phillip                       <NA>                            <NA>                     <NA>                            <NA>                     <NA>                    <NA>                 <NA>                <NA>               <NA>                    <NA>             <NA>                <NA>           <NA>             <NA>            <NA>                    <NA>           <NA>            <NA>                               <NA>            <NA>          <NA>           <NA>              <NA>            <NA>                 <NA>                    <NA>             <NA>             <NA>           <NA>            <NA>                        <NA>                    <NA>                 <NA>                  <NA>          <NA>             <NA>        <NA>           <NA>             <NA>              <NA>              <NA>             <NA>          <NA>          <NA>       <NA>      <NA>             <NA>          <NA>                  <NA>            <NA>

# %%
#CON LOS VALORES SANEDOS Y COMPLETOS, SUMO

#1) Eliminar duplicados por fila:
#    Para cada fila, quedarnos sólo con los valores únicos
DF_speaker_mas_text_nodup = DF_speaker_mas_text.apply(
    lambda row: pd.Series(row.dropna().unique()), axis=1
)

# 2) Contar frecuencia total sin repetir orador en la misma fila
counter = Counter()
def update_counter(row):
    # filtrar NaN y actualizar Counter con los valores de esta fila
    vals = [v for v in row if pd.notna(v)]
    counter.update(vals)

DF_speaker_mas_text_nodup.apply(update_counter, axis=1)

# 3) Crear DF_speaker_tot ordenado de mayor a menor
DF_speaker_tot = (
    pd.DataFrame(counter.items(), columns=['speaker', 'count'])
      .sort_values('count', ascending=False)
      .reset_index(drop=True)
)

# LISTA CON ORADORES DE MAYOR OCURRENCIA A MENOR OCURRENCIA Y CANTIDAD DE DISCURSOS EN LOS QUE APARECEN
print("DF_speaker_tot")
print(DF_speaker_tot.to_string())
# Out:
# DF_speaker_tot
#                                speaker  count
# 0                            joe biden     97
# 1                         donald trump     53
# 2                       bernie sanders     27
# 3                           mike pence     21
# 4                        kamala harris     20
# 5           elizabeth elizabeth warren     12
# 6                       pete buttigieg     11
# 7                        amy klobuchar     10
# 8                          andrew yang      6
# 9                         barack obama      5
# 10                      mike bloomberg      5
# 11                     hillary clinton      4
# 12                         cory booker      4
# 13                      lindsey graham      4
# 14                             jessica      4
# 15                          tom steyer      3
# 16                        nancy pelosi      3
# 17                      jill joe biden      3
# 18                      michelle obama      3
# 19                          ben carson      2
# 20           governor gretchen whitmer      2
# 21                           lou holtz      2
# 22                           pam bondi      2
# 23                    kellyanne conway      2
# 24                        colin powell      2
# 25                                john      2
# 26                       chris wallace      2
# 27                              lauren      2
# 28                         karen pence      2
# 29                    kayleigh mcenany      2
# 30                        bill clinton      2
# 31                      jaime harrison      2
# 32                      mari manoogian      2
# 33                      bernie comfort      2
# 34                    scott richardson      2
# 35                                 rob      2
# 36                      ronna mcdaniel      2
# 37                    garlin gilchrist      2
# 38                           tim scott      2
# 39                     anderson cooper      2
# 40                        andrew cuomo      2
# 41                    kerry washington      2
# 42                   tracee ellis ross      2
# 43                           tom perez      2
# 44                        cindy mccain      2
# 45                           rand paul      2
# 46                                mary      2
# 47                       jim roosevelt      2
# 48                        dan crenshaw      2
# 49                       eric garcetti      2
# 50                   nicholas sandmann      2
# 51                             jeffrey      2
# 52                          doug ducey      2
# 53                       stacey abrams      2
# 54                         lester holt      2
# 55               george stephanopoulos      2
# 56                       julian castro      2
# 57                                gary      2
# 58                    savannah guthrie      2
# 59                       jeff van drew      2
# 60                     mitch mcconnell      2
# 61                      yvanna cancela      2
# 62                                mike      2
# 63                   michael bloomberg      2
# 64                        sean hannity      2
# 65                          dana white      2
# 66                      hallie jackson      2
# 67                       chuck schumer      2
# 68                               terry      2
# 69                         brian smith      2
# 70                       rudy giuliani      2
# 71                               janet      1
# 72                       devin sanders      1
# 73                         todd perdue      1
# 74                       perla canales      1
# 75                     vivian deniston      1
# 76                         chris ellis      1
# 77                          mary bruce      1
# 78                tsoganesh endogoshet      1
# 79                           tom emmer      1
# 80                      mary kay henry      1
# 81                       arturo vargas      1
# 82                     marlyn hoilette      1
# 83                     adriana alvarez      1
# 84                             annette      1
# 85                    ashley joe biden      1
# 86                      senator harris      1
# 87                        peggy vonner      1
# 88                         aysha ahmed      1
# 89                         john kasich      1
# 90                           jen fogle      1
# 91                        pamela owens      1
# 92                       william daley      1
# 93                            nimo ali      1
# 94                          rick lucas      1
# 95                     shanrika nelson      1
# 96                    priscilla castro      1
# 97                        matt yarnell      1
# 98                    cassandra brooks      1
# 99                               randy      1
# 100                   alfredo corchado      1
# 101                       terry thomas      1
# 102                       tia mitchell      1
# 103                    president obama      1
# 104                      errol barnett      1
# 105              christina kolbjornsen      1
# 106                      rhonda miller      1
# 107                       debra dawson      1
# 108    representative carla cunningham      1
# 109                      nury martinez      1
# 110                          bobby roy      1
# 111                      pedro pizarro      1
# 112                      greg anderson      1
# 113                          gwen carr      1
# 114                      maggie rogers      1
# 115                     kathleen clyde      1
# 116                    rosalynn carter      1
# 117                   jack schlossberg      1
# 118                   caroline kennedy      1
# 119                          cameraman      1
# 120                               nick      1
# 121                             denise      1
# 122                              micah      1
# 123                        sally yates      1
# 124                     matthew miller      1
# 125                     raumesh akbari      1
# 126                      brendan boyle      1
# 127                       colin allred      1
# 128                    randall woodfin      1
# 129                     victoria neave      1
# 130                      robert garcia      1
# 131                           bob king      1
# 132                       jonathan nez      1
# 133                         conor lamb      1
# 134                     marlon kimpson      1
# 135                     denny ruprecht      1
# 136                           sam park      1
# 137                   malcolm kenyatta      1
# 138                        nikki fried      1
# 139                       ann richards      1
# 140                        mario cuomo      1
# 141                      daniel inouye      1
# 142                    denis mcdonough      1
# 143             julie chavez rodriguez      1
# 144                       barney frank      1
# 145                      maria cardona      1
# 146                       jimmy carter      1
# 147                    jacquelyn asbie      1
# 148                        sara gideon      1
# 149                      jamira burley      1
# 150                              rhoda      1
# 151                          elizabeth      1
# 152                           victoria      1
# 153                     michelle boyle      1
# 154                      aldo martinez      1
# 155                          trung lee      1
# 156                      megan rapinoe      1
# 157                    kristin urquiza      1
# 158                         kevin penn      1
# 159                        jim clyburn      1
# 160                               sina      1
# 161                      linda sarsour      1
# 162                        art acevedo      1
# 163                     lori lightfoot      1
# 164                       leon bridges      1
# 165                        chris coons      1
# 166                    philonise floyd      1
# 167                      muriel bowser      1
# 168                    derrick johnson      1
# 169                         gwen moore      1
# 170                     michelle beebe      1
# 171                        rick telesz      1
# 172                        marley dias      1
# 173                       eva longoria      1
# 174                   gabriel salguero      1
# 175                          ron klain      1
# 176                      cecilia munoz      1
# 177                        ted kaufman      1
# 178                        john mccain      1
# 179               lisa blunt rochester      1
# 180                         nihad awad      1
# 181                               alex      1
# 182                       rizwan hasan      1
# 183                        jen epstein      1
# 184                    alexandra jaffe      1
# 185                            arlette      1
# 186                      tulsi gabbard      1
# 187                          dana bash      1
# 188                      ilia calderón      1
# 189                        jake tapper      1
# 190                     amy langenfeld      1
# 191                          sade reed      1
# 192                        mike duggan      1
# 193                    brenda lawrence      1
# 194                     michael bivins      1
# 195                       sandra smith      1
# 196                      donna brazile      1
# 197                           ed henry      1
# 198                        thom tillis      1
# 199                        gabe fisher      1
# 200                   trevor hunnicutt      1
# 201                      khurrum wahid      1
# 202                       jessica dean      1
# 203                      steve mnuchin      1
# 204                    carlia alderman      1
# 205                      michelle kwan      1
# 206                            al gore      1
# 207                      shervin jones      1
# 208                    safaa elzakzoky      1
# 209                        jerry brown      1
# 210                      shevrin jones      1
# 211                       kris holtham      1
# 212                     lavette jacobs      1
# 213                               judy      1
# 214                        leah dudley      1
# 215                              frank      1
# 216                     ken washington      1
# 217                        bill barrow      1
# 218                           o’rourke      1
# 219                     henry mcmaster      1
# 220                         gayle king      1
# 221                      bill whitaker      1
# 222                     anders helberg      1
# 223                            sanders      1
# 224                               macy      1
# 225                             judith      1
# 226                              april      1
# 227                       jane sanders      1
# 228               congresswoman kuster      1
# 229                            lindsey      1
# 230                         david muir      1
# 231                   monica hernandez      1
# 232                        adam sexton      1
# 233                       linsey davis      1
# 234                       kim reynolds      1
# 235                      sarah sanders      1
# 236                       wolf blitzer      1
# 237                              nancy      1
# 238                                amy      1
# 239                             rhonda      1
# 240                       kelly brooks      1
# 241                      major garrett      1
# 242                   margaret brennan      1
# 243                    pete buttigieig      1
# 244                      amy klobucher      1
# 245                      mike eruzione      1
# 246                          jim craig      1
# 247                governor doug ducey      1
# 248                              brett      1
# 249                     martha mcsally      1
# 250                         chuck todd      1
# 251                       vanessa hauc      1
# 252                        jon ralston      1
# 253                              helen      1
# 254                              scott      1
# 255                                joe      1
# 256                              moise      1
# 257                       phil tulkoff      1
# 258                   stephanie miller      1
# 259                           judy chu      1
# 260          represenative mark takano      1
# 261     representative tammy duckworth      1
# 262            representative ted lieu      1
# 263     representative pramila jayapal      1
# 264            representative andy kim      1
# 265                      jong vang tao      1
# 266                    vimila rejenjun      1
# 267                            kirsten      1
# 268                        don cheadle      1
# 269                          nila cobb      1
# 270                        ryan wilson      1
# 271                    jameesha harris      1
# 272                        keith james      1
# 273                  governor tom wolf      1
# 274                      khelan bhatia      1
# 275                        daphne kwok      1
# 276                       stephen gong      1
# 277                        james comey      1
# 278                         kanye west      1
# 279                             summer      1
# 280                            georgia      1
# 281                             shiloh      1
# 282                             kaylee      1
# 283                  mary donald trump      1
# 284                      lily eskelsen      1
# 285                     christine chen      1
# 286           turquoise lejeune parker      1
# 287                              paula      1
# 288                         jimbo lamb      1
# 289                    bennie thompson      1
# 290                         amna nawaz      1
# 291                       vicky nguyen      1
# 292         representative val demings      1
# 293                           ron kind      1
# 294                    kylie patterson      1
# 295                      mary freibert      1
# 296                    sindy benavides      1
# 297                         bret baier      1
# 298                   martha maccallum      1
# 299                        shayna cruz      1
# 300                         sara polon      1
# 301                        danny lemos      1
# 302                     kristen murray      1
# 303                    rebecca johnson      1
# 304                    leslie coffield      1
# 305                               dena      1
# 306                       carol mcneil      1
# 307                          mary rose      1
# 308                               mark      1
# 309                    carolyn perkins      1
# 310                  secretary mnuchin      1
# 311                     joaquin castro      1
# 312                  chairman thompson      1
# 313                       filemon vela      1
# 314                       jaylen geist      1
# 315                                ron      1
# 316                         rob grover      1
# 317                   gretchen whitmer      1
# 318                        phil murphy      1
# 319                         ned lamont      1
# 320                  marvin zanders ii      1
# 321                      veronica ward      1
# 322          congresswoman zoe lofgren      1
# 323                               leta      1
# 324                 congressman lawson      1
# 325                     domingo garcia      1
# 326                     nancy feregoso      1
# 327                          alejandro      1
# 328                            edgardo      1
# 329                    lorraine miller      1
# 330                       david perdue      1
# 331                        tom barrett      1
# 332             rajon williams jackson      1
# 333                      hannah cannon      1
# 334                    matt campanario      1
# 335                 senator tina smith      1
# 336                     governor ducey      1
# 337                       janet mendez      1
# 338                      brian mueller      1
# 339                    jovita carranza      1
# 340                       daniel garza      1
# 341                       mark meadows      1
# 342                        jane timken      1
# 343                        larry obhof      1
# 344                marloshawn franklin      1
# 345                      james johnson      1
# 346                   jeremiah wheeler      1
# 347                    wendell anthony      1
# 348                             cheryl      1
# 349                     malcolm graham      1
# 350                       andrea brown      1
# 351                   hannah bonaparte      1
# 352                         chris paul      1
# 353                     mayor vi lyles      1
# 354                     fabio andretti      1
# 355                  carolina ferreiro      1
# 356                        hiram turil      1
# 357                   carla salvatiras      1
# 358                            claudia      1
# 359                               juan      1
# 360                              erica      1
# 361                           santiago      1
# 362                        joe gruters      1
# 363                    cherelle parker      1
# 364                      latifa fields      1
# 365                   chairman russell      1
# 366                         kelli ward      1
# 367                      ruben roberts      1
# 368                      rhonda thomas      1
# 369                    jaffus hardrick      1
# 370                       eric knowles      1
# 371                   frederica wilson      1
# 372                     crystal wagars      1
# 373                     justin gaethje      1
# 374                          pam kirby      1
# 375              leah marquez peterson      1
# 376                      moses sanchez      1
# 377                        jorge rivas      1
# 378                       jimmy chavez      1
# 379                             gloria      1
# 380                               arte      1
# 381                      deshaun hienz      1
# 382                        selema pace      1
# 383                      lauren weiner      1
# 384                          alexandra      1
# 385                       jim roudeski      1
# 386                     ellesia blaque      1
# 387                     leah schwotzer      1
# 388                    pastor carl day      1
# 389                       laura galvis      1
# 390                      johnny powell      1
# 391                         julie bard      1
# 392                       paul tubiana      1
# 393                           meredith      1
# 394                            caitlin      1
# 395                             lasora      1
# 396                             evelyn      1
# 397                         angela rye      1
# 398                      lottie joiner      1
# 399                     barbara jordan      1
# 400                      adam schucher      1
# 401                         susan page      1
# 402                              maria      1
# 403                       louis yuhasz      1
# 404                     carolyn murray      1
# 405                        gordon dill      1
# 406                           amy wood      1
# 407                     jamie harrison      1
# 408                         toby feuer      1
# 409                    damian ferguson      1
# 410                  pedro fuentes cid      1
# 411                       david rouzer      1
# 412                      paulette dale      1
# 413                        cindy velez      1
# 414                       moriah geene      1
# 415           cristy montesinos alonso      1
# 416                           jonathan      1
# 417                           savannah      1
# 418                      isabella peña      1
# 419                       barbara peña      1
# 420                    jacqueline lugo      1
# 421                       andrew lewis      1
# 422                      nathan osburn      1
# 423                 angelia politarhos      1
# 424              george stephanopoulus      1
# 425                    cedric humphrey      1
# 426                     anthony archer      1
# 427                          kelly lee      1
# 428                       nicholas fed      1
# 429                       ron desantis      1
# 430                              seema      1
# 431                    vanessa tamariz      1
# 432                        chris hayes      1
# 433                    kamilia landrum      1
# 434                       matt hoffman      1
# 435                           herschel      1
# 436                     keisha bottoms      1
# 437                           pat yoes      1
# 438                       pete hegseth      1
# 439                         lynn kerry      1
# 440                      robin sanders      1
# 441                         lori jones      1
# 442                        marcus bass      1
# 443                       lavon barnes      1
# 444                     devonte wilson      1
# 445                      tiffany davis      1
# 446                    marvin mcmickle      1
# 447                     james callahan      1
# 448                      frank spencer      1
# 449                      steve sisolak      1
# 450                    nicolle wallace      1
# 451                         dina titus      1
# 452                        adam mencer      1
# 453                      alonzo julian      1
# 454                     richard rogers      1
# 455                         mike cihla      1
# 456                      eric weisfeld      1
# 457                         joe bustos      1
# 458                        bill sharpe      1
# 459                     peter gonzalez      1
# 460                     ismael illiano      1
# 461                    danny lavendera      1
# 462                          hota kotb      1
# 463                      nicole maddox      1
# 464              michelle cruz marrero      1
# 465                     richard trumka      1
# 466                               rich      1
# 467                       corey birkel      1
# 468                     daniel dae kim      1
# 469               keisha lance bottoms      1
# 470                senator chris coons      1
# 471             sister simone campbell      1
# 472         major general frank vavala      1
# 473                    fred guttenberg      1
# 474                    brittney hubert      1
# 475             luz chaparro hernandez      1
# 476                mayor robert garcia      1
# 477                   vilissa thompson      1
# 478                      miyoko hikiji      1
# 479                       robyn senior      1
# 480                        danica roem      1
# 481  senator elizabet elizabeth warren      1
# 482             senator yvanna cancela      1
# 483                     susan molinari      1
# 484                    elijah cummings      1
# 485                 judge lina hidalgo      1
# 486                         ady barkan      1
# 487                         khizr khan      1
# 488                       donna hylton      1
# 489                 senator daug jones      1
# 490                     dolores huerta      1
# 491                        jon meachin      1
# 492              governor gavin newsom      1
# 493                      amanda litman      1
# 494                         jim jordan      1
# 495                        nikki haley      1
# 496                    herschel walker      1
# 497                 kimberly guilfoyle      1
# 498                           amy ford      1
# 499                       andrew young      1
# 500                         john lewis      1
# 501                      kennita jones      1
# 502                     gabby giffords      1
# 503                       john kennedy      1
# 504                 franklin roosevelt      1
# 505                       lucy sanchez      1
# 506                            estella      1
# 507                      billie eilish      1
# 508                  katherine lorenzo      1
# 509                     andrew adamski      1
# 510              alexandria villaseñor      1
# 511                                kid      1
# 512                      justin onwenu      1
# 513             michelle lujan grisham      1
# 514                             claire      1
# 515                            matthew      1
# 516                               kyle      1
# 517                      deandra dycus      1
# 518                    raphael warnock      1
# 519                              debra      1
# 520                            michael      1
# 521                              garry      1
# 522                     terry williams      1
# 523                         jim bognet      1
# 524                       gavin newsom      1
# 525                     jocelyn benson      1
# 526                       alex padilla      1
# 527                                pat      1
# 528                            seymour      1
# 529                              james      1
# 530                               sara      1
# 531                        deb haaland      1
# 532                        jon meacham      1
# 533                         kim klacik      1
# 534                         matt gaetz      1
# 535                     tanya weinreis      1
# 536                       tim tompkins      1
# 537                       debbie flood      1
# 538                         sean reyes      1
# 539                        dan scavino      1
# 540                   stacia brightmon      1
# 541                           michelle      1
# 542                     kevin mccarthy      1
# 543                    franklin graham      1
# 544                      maxine waters      1
# 545                     laura ingraham      1
# 546                           marjorie      1
# 547                   alderman kennedy      1
# 548                  angela cunningham      1
# 549                       barb deburgh      1
# 550                       jeff weidner      1
# 551                         tim mahone      1
# 552                 rebecca friedrichs      1
# 553                    reverend barker      1
# 554                              isaac      1
# 555                         ketha otis      1
# 556                       arrion brown      1
# 557                          mike hora      1
# 558                charlotte mccracken      1
# 559                       danny groves      1
# 560                      sellers davis      1
# 561                         fawn slade      1
# 562                      jessica gavin      1
# 563                      pamela lawson      1
# 564                    rebecca vedrine      1
# 565                      emily bombich      1
# 566                       alicia urena      1
# 567                         judy smith      1
# 568                    manuel martinez      1
# 569                      claudia perez      1
# 570                    carmen quinones      1
# 571                       charlie kirk      1
# 572               tiffany donald trump      1
# 573                  eric donald trump      1
# 574                        mike pompeo      1
# 575               melania donald trump      1
# 576                        trevor noah      1
# 577                       abby johnson      1
# 578                 bob vlaisavljevich      1
# 579                cissie graham lynch      1
# 580                      john peterson      1
# 581                       larry kudlow      1
# 582                      chris pearson      1
# 583                        jason joyce      1
# 584                     richard blakey      1
# 585                       jamie ponder      1
# 586                     richard beasly      1
# 587                         jon ponder      1
# 588                        jack brewer      1
# 589                  lara donald trump      1
# 590                    chen guangcheng      1
# 591                     michael mchale      1
# 592                  sister dede byrne      1
# 593                         tera myers      1
# 594                      keith kellogg      1
# 595                   marsha blackburn      1
# 596                        kristi noem      1
# 597                         tom cotton      1
# 598                ivanka donald trump      1
# 599                          ann dorin      1
# 600                       abby phillip      1

# %%
# # ------>  FINALMENTE los 5 candidatos/as con mayor cantidad de discursos.

top_5_candidatos = DF_speaker_tot.head(5).reset_index(drop=True)

print("top_5_candidatos")
print(top_5_candidatos)
# Out:
# top_5_candidatos
#           speaker  count
# 0       joe biden     97
# 1    donald trump     53
# 2  bernie sanders     27
# 3      mike pence     21
# 4   kamala harris     20

# %%
# TODO: Visualización de los discursos de cada candidato a lo largo del tiempo 

# 1) Crear DataFrame Top_5 a partir de DF_speaker_tot
Top_5 = pd.DataFrame({
    'top_5': DF_speaker_tot['speaker'].head(5)
}).reset_index(drop=True)

# Ahora Top_5 tiene una columna 'Top_5' y cinco filas, con los nombres de los 3 candidatos.

# 2) Para cada uno de esos cinco candidatos, construir un DF_fecha_candidatoN
#    que capture las filas de DF_speaker_mas_text donde aparece el candidato,
#    junto con la fecha correspondiente de df_speeches.

for i, candidato in enumerate(Top_5['top_5'], start=1):
    # Filtrar filas donde ANY column in DF_speaker_mas_text coincida con el nombre del candidato
    mask = DF_speaker_mas_text.apply(lambda row: row.eq(candidato).any(), axis=1)
    
    # Crear DataFrame para este candidato
    df_fecha = pd.DataFrame({
        'candidato': DF_speaker_mas_text.index[mask].map(lambda idx: candidato),
        'date': df_speeches.loc[DF_speaker_mas_text.index[mask], 'date']
    }).reset_index(drop=True)
    
    # Asignar a variable dinámica DF_fecha_candidato{i}
    globals()[f'DF_fecha_candidato{i}'] = df_fecha

    # Mostrar 
    # print(f"DF_fecha_candidato{i} para {candidato}:")
    # print(df_fecha.head(), '\n')

# %%
# Crear nueva columna con todos los oradores únicos por fila
oradores = DF_speaker_mas_text.copy()

# Generar columna con lista de strings únicos
oradores["oradores_finales"] = oradores.apply(
    lambda row: list({v for v in row if isinstance(v, str)}),
    axis=1
)

# Extraer solo la columna final, con el índice correcto
col_oradores_finales = oradores["oradores_finales"]

# Agregar resultado de oradores finales (oradores extraídos de speaker y de text))
df_speeches["oradores_finales"] = col_oradores_finales

# Visualizar
# df_speeches.head(10)

# %%
# Crear una nueva columna 'text1' con el texto normalizado (minusculas y nombres estandarizados o none)
df_speeches['text1'] = df_speeches['text'].apply(normalize_names)

# Visualizar
# df_speeches.head(10)

# %%
# Extrae el texto correspondiente a cada orador en una columna, para cada uno de los top 5 oradores.

def extraer_intervenciones_por_orador(texto, oradores_normalizados):
    
    # Si el contenido no es un string (por ejemplo, NaN), devolver diccionario con textos vacíos
    if not isinstance(texto, str):
        return {orador: "" for orador in oradores_normalizados}

    # Compilar patrón regex que detecta encabezados de intervenciones en el formato:
    # salto de línea + Nombre Apellido: (mm:ss) o (hh:mm:ss)
    # inicio de línea  + Nombre Apellido: (mm:ss) o (hh:mm:ss)
    patron = re.compile(r'(?:^|\n)([A-Za-z \.]+): \(\d{2}:\d{2}(?::\d{2})?\)', flags=re.MULTILINE)

    bloques = [] # Lista donde se guardarán tuplas (orador_normalizado, segmento de texto)
    matches = list(patron.finditer(texto)) # Buscar todos los encabezados que matcheen el patrón
 
    # Iterar sobre todos los encabezados encontrados
    for i in range(len(matches)):
        nombre_crudo = matches[i].group(1).strip().lower() # Extraer nombre crudo del encabezado
        nombre_crudo = normalize_names(nombre_crudo)  # Normalizar nombre (según reglas definidas)

        # Definir el segmento del texto que corresponde a esa intervención
        inicio = matches[i].start()
        fin = matches[i + 1].start() if i + 1 < len(matches) else len(texto)
        segmento = texto[inicio:fin].strip()

        bloques.append((nombre_crudo, segmento)) # Guardar orador y su fragmento de texto

    # Crear diccionario con oradores como claves y texto acumulado como valor inicial vacío
    resultado = {orador: "" for orador in oradores_normalizados}
    
    # Completar el diccionario sólo con los oradores indicados (top 3)
    for orador, fragmento in bloques:
        if orador in resultado:
            resultado[orador] += fragmento + "\n" # Acumular texto correspondiente al orador

    return resultado

# Obtener lista de los 5 oradores principales desde Top_5_candidatos
top_5_oradores = top_5_candidatos['speaker'].tolist()

# Aplicar función de extracción a cada fila del DataFrame y expandir resultados como columnas nuevas
df_speeches[top_5_oradores] = df_speeches['text1'].apply(
    lambda t: pd.Series(extraer_intervenciones_por_orador(t, top_5_oradores))
)

# df_speeches.to_excel("df_speeches_con_texto_por_orador.xlsx", index=False)

# Visualizar
#df_speeches

# %%
# Crear un DataFrame con los discursos de los 5 candidatos más frecuentes
nombres_Top_5 = top_5_candidatos['speaker'].tolist()

# Filtrar filas donde al menos uno de los nombres del top 5 aparece en la columna "oradores_finales"
df_speeches_Top_5 = df_speeches[
    df_speeches["oradores_finales"].apply(lambda lista: any(orador in nombres_Top_5 for orador in lista))
].copy()

# Revisar el shape
print(df_speeches.shape)
print(df_speeches_Top_5.shape)
# Out:
# (269, 13)
# (194, 13)

# %%
##  Toma como entrada las columnas con los discursos de los top 5 oradores, y reemplaz el nombre del orador : (MM:SS) por ' // '

def limpiar_encabezados(texto):
    """
    Reemplaza encabezados de orador (Ej. 'trump: (00:30)') por ' // '.
    
    """
    # Si el valor no es texto (por ejemplo, es NaN o None), lo deja sin cambios
    if not isinstance(texto, str):
        return texto
    
    # Busca patrones como "nombre apellido: (00:30)" o "(00:30:45)" y los reemplaza por " // "
    texto = re.sub(r'[A-Za-z \.]+: \(\d{2}:\d{2}(?::\d{2})?\)', 
                   ' // '           # texto por el que se reemplaza
                   , texto)

    return texto

# Aplica la función a las columnas de los top 5 oradores
for orador in top_5_oradores:
    df_speeches[orador] = df_speeches[orador].apply(limpiar_encabezados)

df_speeches_sin_encabezados = df_speeches.copy()

# %%
# Creación de clean_text acorde a mis necesidades

def clean_text(df, column_name):
    """
    Normaliza texto eliminando encabezados, puntuación, tildes y convirtiendo a minúsculas.
    Esto permite un conteo de palabras consistente.
    """
    result = df[column_name]

    # 1. Eliminar cualquier encabezado hasta el primer salto de línea
    # Justificación: Muchas transcripciones comienzan con metadatos irrelevantes como "TRUMP: (00:30)"
    result = result.str.replace(r"^[^\n]*\n", "", regex=True)

    # 2. Convertir todo a minúsculas
    # Justificación: Para que "You", "you", "YOU" se cuenten como la misma palabra
    result = result.str.lower()

    # 3. Eliminar acentos (tildes) y caracteres diacríticos
    # Justificación: Para unificar palabras como “señor” y “senor”
    result = result.apply(lambda x: unicodedata.normalize("NFKD", x).encode("ASCII", "ignore").decode("utf-8") if isinstance(x, str) else x)

    # 4. Reemplazar signos de puntuación por espacios
    # Justificación: Para evitar que "you.", "you,", "you!" se cuenten como palabras distintas
    # Se incluye un conjunto extendido de puntuación: comillas, guiones largos, etc.
    signos_extra = '“”‘’–—'
    tabla = str.maketrans(string.punctuation + signos_extra, ' ' * (len(string.punctuation) + len(signos_extra)))
    result = result.str.translate(tabla)

    # 5. Reemplazar múltiples espacios por uno solo y eliminar espacios laterales
    # Justificación: Limpieza final para evitar errores en tokenización
    result = result.str.replace(r'\s+', ' ', regex=True).str.strip()

    return result

# %%
df_speeches_sin_encabezados.head(2)
# Out:
#         speaker                                              title  \
# 0  David Perdue  Georgia Sen. David Perdue Speech Transcript at...
# 1     Joe Biden  Joe Biden Southfield, MI Speech on Health Care...
#
#                                                 text          date  \
# 0  David Perdue: (00:01)\nHow great is it to be b...  Oct 16, 2020
# 1  Joe Biden: (00:00)\nHello, Michigan. Hi, how a...  Oct 16, 2020
#
#                location             type oradores_finales  \
# 0        Macon, Georgia  Campaign Speech   [david perdue]
# 1  Southfield ,Michigan  Campaign Speech      [joe biden]
#
#                                                text1  \
# 0  david perdue: (00:01)\nhow great is it to be b...
# 1  joe biden: (00:00)\nhello, michigan. hi, how a...
#
#                                            joe biden donald trump  \
# 0
# 1   // \nhello, michigan. hi, how are you? what’s...
#
#   bernie sanders mike pence kamala harris
# 0
# 1

# %% [markdown]
# Hasta Acá salió todo de la Tarea1

# %% [markdown]
# ## Preparar Dataframe para clasificar discursos

# %%
# Realizar la limpieza de los datos que crea pertinente. Se espera que usen la función clean_text() de la entrega anterior.
# df_speeches_clean = ...

# %%
# Filtramos los 3 candidatos con más discursos.

# Top_5_candidates = df_speeches_clean["speaker"].value_counts().head(5).index
# print(f"Top 3 candidatos: {Top_5_candidates}")
# print("---------------")

# df_speeches_Top_5 = df_speeches_clean[
#     df_speeches_clean["speaker"].isin(Top_5_candidates)
# ]
# df_speeches_Top_5

# %%
# Paso 1: seleccionar columnas
df_reducido = df_speeches_sin_encabezados[['text1', 'joe biden', 'donald trump', 'bernie sanders']].copy()

# Paso 2: melt
df_melted = df_reducido.melt(
    id_vars='text1',
    value_vars=['joe biden', 'donald trump', 'bernie sanders'],
    var_name='target',
    value_name='text_orador'
)

# Paso 3: eliminar vacíos/nulos
df_melted = df_melted[df_melted['text_orador'].notna() & (df_melted['text_orador'].str.strip() != '')].reset_index(drop=True)

# Paso 4: aplicar limpieza
df_melted['clean_text'] = clean_text(df_melted, 'text_orador')

# %%
df_melted['target'].value_counts()
# Out:
# target
# joe biden         101
# donald trump       60
# bernie sanders     27
# Name: count, dtype: int64

# %%
## Verificamos

# Función auxiliar: cuenta celdas con texto no vacío
def contar_textos_no_vacios(df, columnas):
    return sum((df[col].str.strip() != '').sum() for col in columnas)

# Columnas que nos interesan
columnas_oradores = ['joe biden', 'donald trump', 'bernie sanders']

# Conteo real de celdas con texto en el DataFrame original
conteo_original = contar_textos_no_vacios(df_speeches_sin_encabezados, columnas_oradores)

# Conteo de filas en el nuevo DataFrame ya "derretido"
conteo_melted = len(df_melted)

print(f"Cantidad de celdas con texto en columnas originales: {conteo_original}")
print(f"Cantidad de filas en el nuevo DataFrame: {conteo_melted}")

if conteo_original == conteo_melted:
    print("✅ Coinciden: no se perdió información.")
else:
    print("⚠️ No coinciden: hay pérdida o exceso de datos.")
# Out:
# Cantidad de celdas con texto en columnas originales: 188
# Cantidad de filas en el nuevo DataFrame: 188
# ✅ Coinciden: no se perdió información.

# %%
# Crear un Dataframe que solo contiene las columnas para Clasificación
df_clf = df_melted[['clean_text', 'target']]

# %%
df_clf.shape
# Out:
# (188, 2)

# %%
df_clf.isna().sum()
# Out:
# clean_text    0
# target        0
# dtype: int64

# %%
df_clf.head(2)
# Out:
#                                           clean_text     target
# 0  hello michigan hi how are you whats your name ...  joe biden
# 1  good to be with you okay i know it well well f...  joe biden

# %% [markdown]
# ## Parte 1: Dataset y representación numérica de texto

# %%
# 1: Separar 30% del conjunto para test. Al resto lo llamamos "dev" (desarrollo).

# Variables originales
X = df_clf['clean_text']
y = df_clf['target']

# División estratificada para mantener proporciones por clase
X_dev, X_test, y_dev, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

# Mostrar tamaños de los conjuntos
print(f"Tamaños de los conjuntos: dev = {X_dev.shape}, test = {X_test.shape}")
print(f"Tamaños de los conjuntos: dev = {y_dev.shape}, test = {y_test.shape}")
# Out:
# Tamaños de los conjuntos: dev = (131,), test = (57,)
# Tamaños de los conjuntos: dev = (131,), test = (57,)

# %%
# 2: Visualización de la proporción de cada candidato por conjunto

# Conteo de discursos por orador en cada conjunto
print("Distribución en el conjunto de desarrollo (dev):")
print(y_dev.value_counts())

print("\nDistribución en el conjunto de test:")
print(y_test.value_counts())
# Out:
# Distribución en el conjunto de desarrollo (dev):
# target
# joe biden         70
# donald trump      42
# bernie sanders    19
# Name: count, dtype: int64
#
# Distribución en el conjunto de test:
# target
# joe biden         31
# donald trump      18
# bernie sanders     8
# Name: count, dtype: int64

# %%
# Conteo por clase
conteo_train = y_dev.value_counts().sort_index()
conteo_test = y_test.value_counts().sort_index()

# Asegurar orden consistente de candidatos
candidatos = sorted(set(conteo_train.index) | set(conteo_test.index))
conteo_train = conteo_train.reindex(candidatos, fill_value=0)
conteo_test = conteo_test.reindex(candidatos, fill_value=0)

# Posiciones
x = np.arange(len(candidatos))
width = 0.35

# Gráfico
fig, ax = plt.subplots(figsize=(10, 6))

bars1 = ax.bar(x - width/2, conteo_train, width, label='Train', color='skyblue')
bars2 = ax.bar(x + width/2, conteo_test, width, label='Test', color='lightgreen')

# Ejes
ax.set_ylabel('Cantidad de discursos', fontsize=13)
ax.set_title('Distribución de discursos por candidato', fontsize=20, pad=20)
ax.set_xticks(x)
ax.set_xticklabels(candidatos, fontsize=12, fontweight='bold', rotation=0)
ax.legend()

# Etiquetas sobre las barras
for bar in bars1 + bars2:
    height = bar.get_height()
    ax.text(bar.get_x() + bar.get_width()/2., height + 0.5,
            f'{int(height)}', ha='center', va='bottom', fontsize=14, fontweight='bold')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Desbalanceo de clases en el conjunto de discursos
#
# Al analizar la distribución de discursos por orador en los conjuntos de entrenamiento (dev) y test, se observa un **desbalanceo importante** entre clases:
#
# - **Joe Biden** domina el conjunto, con más del doble de ejemplos que **Donald Trump**, y casi cuatro veces más que **Bernie Sanders**.
# - **Bernie Sanders** tiene muy pocos discursos disponibles (19 en entrenamiento y solo 8 en test).

# %%
# 3: Transforme el texto del conjunto de entrenamiento a la representación numérica (features) de conteo de palabras o bag of words.

# Crear el vectorizador y ajustarlo al conjunto de desarrollo
count_vect = CountVectorizer()

# Aplicar fit_transform para construir el vocabulario y transformar el texto
X_dev_counts = count_vect.fit_transform(X_dev)

# Mostrar forma de la matriz resultante
print("Shape de la matriz de conteo (Bag of Words):", X_dev_counts.shape)
# Out:
# Shape de la matriz de conteo (Bag of Words): (131, 13068)

# %%
X_dev_counts
# Out:
# <131x13068 sparse matrix of type '<class 'numpy.int64'>'
# 	with 129227 stored elements in Compressed Sparse Row format>

# %%
# 4: Obtenga la representación numérica Term Frequency - Inverse Document Frequency.

# Crear el transformador TF-IDF
tfidf_transformer = TfidfTransformer()

# Ajustar al conjunto de desarrollo y transformar
X_dev_tfidf = tfidf_transformer.fit_transform(X_dev_counts)

# Mostrar la shape de la matriz resultante
print("Shape de la matriz TF-IDF:", X_dev_tfidf.shape)
# Out:
# Shape de la matriz TF-IDF: (131, 13068)

# %%
# 5 :Muestre en un mapa el conjunto de entrenamiento, utilizando las dos primeras componentes PCA sobre los vectores de tf-idf.

# Convertimos la matriz dispersa a array denso
X_dense = X_dev_tfidf.toarray()

# Aplicamos PCA para reducir a 2 dimensiones
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_dense)

# Graficamos en 2D con colores por orador
plt.figure(figsize=(8, 6))

for label in y_dev.unique():
    idx = y_dev == label
    plt.scatter(X_pca[idx, 0], X_pca[idx, 1], label=label, alpha=0.7)

plt.title("Mapa del conjunto de entrenamiento por orador con dos componentes del PCA")
plt.xlabel("Componente principal 1")
plt.ylabel("Componente principal 2")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Mapa PCA en 2D
#
# Asumimos que el PCA con 2 componentes está usando las **dos palabras (o combinaciones de palabras)** más importantes del corpus, es decir, las que más varianza explican entre los discursos.
#
#     - Cada punto del gráfico representa un discurso, transformado en números a partir del uso de palabras.
#
#     - Las posiciones en el plano (eje X y eje Y) reflejan cuánto "puntaje" tiene cada discurso en esas dos palabras principales que detectó el PCA.
#
# **¿Qué muestra el gráfico?**
#
# - **Eje X (Componente 1):** Parece capturar una diferencia clara entre Trump y los demás. Los discursos naranjas (Trump) están agrupados hacia la derecha : usa palabras distintas.
# - **Eje Y (Componente 2):** Podría estar capturando diferencias más sutiles, quizás entre Biden y Sanders.
#
# **Agrupamiento por color (orador):**
# - 🟠 **Trump (naranja):** Bien separado : su estilo o vocabulario es muy distintivo.
# - 🔵 **Biden (azul):** Se agrupa, pero más disperso : su lenguaje es más variado.
# - 🟢 **Sanders (verde):** Más mezclado : puede compartir palabras con ambos y además tiene menos ejemplos, lo que afecta su representación.
#
# El gráfico nos da una pista visual de qué tan diferentes (o parecidos) son los discursos según las palabras que más varían entre candidatos.

# %%
# Haga una visualización que permita entender cómo varía la varianza explicada a medida que se agregan componentes (e.g: hasta 10 componentes).

# Guardamos la varianza explicada acumulada para cada cantidad de componentes
varianzas = []

for n in range(2, 11):  # De 2 a 10 componentes
    pca = PCA(n_components=n)
    pca.fit(X_dense)
    var_exp = np.sum(pca.explained_variance_ratio_)
    varianzas.append(var_exp)

# Gráfico
plt.figure(figsize=(8, 5))
plt.plot(range(2, 11), varianzas, marker='o')
plt.xticks(range(2, 11))
plt.xlabel('Cantidad de componentes PCA')
plt.ylabel('Varianza explicada total')
plt.title('Varianza explicada total según cantidad de componentes PCA')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Conclusión: Análisis de PCA
#
# - Se aplicó **Análisis de Componentes Principales (PCA)** sobre los vectores TF-IDF del conjunto de entrenamiento para explorar la estructura del corpus.
# - Se entrenaron múltiples modelos de PCA variando la cantidad de componentes desde 2 hasta 10, y se observó cómo varía la **varianza explicada total**.
#
# #### Observaciones:
#
# - Las dos primeras componentes de PCA explican solo una pequeña fracción de la varianza (aprox. 10%).
# - A medida que se agregan más componentes, la varianza explicada crece gradualmente, pero de forma lenta: con 10 componentes apenas se supera el 40%.
# - Esto indica que el corpus tiene una **estructura dispersa**: la información está distribuida entre muchas palabras (features), sin que pocas componentes capten la mayoría de la variabilidad.

# %% [markdown]
# ## Análisis Extra

# %%
# Cantidad máxima de componentes a utilizar (Cantidad de componentes no puede superar la cantidad de muestras)
n_samples, n_features = X_dense.shape
max_componentes = min(n_samples, n_features)
print(f"Podés usar como máximo {max_componentes} componentes.")
# Out:
# Podés usar como máximo 131 componentes.

# %%
# Encontrar el número mínimo de componentes que explican al menos el 99% de la varianza
for i, var_exp in enumerate(varianzas, start=2):  # empieza en 2 porque empezamos el for desde n=2
    if var_exp >= 0.99:
        print(f"Se necesitan al menos {i} componentes para explicar el 99% de la varianza.")
        break

# %%
## Hacer el mismo gráfico con más componentes para entender cuantas necesitamos para explicar el 99% de la varianza

# Guardamos la varianza explicada acumulada
varianzas = []

for n in range(2, 122):  # De 2 a 121 componentes
    pca = PCA(n_components=n)
    pca.fit(X_dense)
    var_exp = np.sum(pca.explained_variance_ratio_)
    varianzas.append(var_exp)

# Gráfico
plt.figure(figsize=(10, 6))
plt.plot(range(2, 122), varianzas, marker='o')
plt.axhline(0.99, color='red', linestyle='--', label='99% de varianza explicada')
plt.xticks(range(0, 122, 10))
plt.xlabel('Cantidad de componentes PCA')
plt.ylabel('Varianza explicada total')
plt.title('Varianza explicada total según cantidad de componentes PCA (hasta 131)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Varianza explicada y dimensionalidad
#
# - La gráfica muestra cómo crece la varianza explicada total del PCA al aumentar la cantidad de componentes.
# - Se observa que el crecimiento es gradual y no se alcanza el 99% de varianza explicada hasta aproximadamente 120 componentes.
# - Esto confirma que el conjunto de discursos tiene **alta dimensionalidad efectiva**, es decir, la información está repartida en muchas palabras relevantes.
# - Para tareas como clasificación, podría ser necesario conservar una cantidad considerable de componentes o trabajar directamente sobre TF-IDF sin reducir dimensiones si se busca preservar el máximo de información.

# %%
### Agregado

# %%
# Muestre en un mapa el conjunto de entrenamiento, utilizando las dos primeras componentes PCA sobre los vectores de tf-idf. Analice los resultados y 
# compare qué sucede si utiliza el filtrado de stop_words para idioma inglés, el parámetro use_idf=True y ngram_range=(1,2). 
# Opcionalmente, también puede analizar qué sucede si no elimina los signos de puntuación.

# Definimos la lista de comparaciones (pares)
pares = [
    ("default", {"stop_words": None, "ngram_range": (1, 1)}),
    ("stopwords_en", {"stop_words": "english", "ngram_range": (1, 1)}),
    ("ngram_1_2", {"stop_words": None, "ngram_range": (1, 2)}),
    ("stop_en_ngram_1_2", {"stop_words": "english", "ngram_range": (1, 2)}),
    ("keep_punctuation", {
        "stop_words": None,
        "ngram_range": (1, 1),
        "token_pattern": r"(?u)\b\w+\b|[^\w\s]"
    })
]

# Orden de etiquetas deseado para mantener colores consistentes por defecto
orden_etiquetas = ["joe biden", "donald trump", "bernie sanders"]

for nombre, params in pares[1:]:
    fig, axes = plt.subplots(1, 2, figsize=(14, 6), sharex=True, sharey=True)

    for i, (titulo, p) in enumerate([("default", pares[0][1]), (nombre, params)]):
        # Paso 1: Vectorización
        count_vectorizer = CountVectorizer(**p)
        X_counts = count_vectorizer.fit_transform(X_dev)

        # Paso 2: TF-IDF
        tfidf_transformer = TfidfTransformer()
        X_tfidf = tfidf_transformer.fit_transform(X_counts)

        # Paso 3: PCA
        X_dense = X_tfidf.toarray()
        pca = PCA(n_components=2)
        X_pca = pca.fit_transform(X_dense)

        # Paso 4: Gráfico con orden de etiquetas fijado
        ax = axes[i]
        for label in orden_etiquetas:
            idx = y_dev == label
            ax.scatter(X_pca[idx, 0], X_pca[idx, 1], label=label, alpha=0.7)
        ax.set_title(f"PCA - {titulo}")
        ax.set_xlabel("Componente 1")
        ax.set_ylabel("Componente 2")
        ax.grid(True)

    axes[1].legend()
    plt.suptitle(f"Comparación: default vs {nombre}", fontsize=14)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Análisis comparativo de configuraciones TF-IDF + PCA (2D)
#
# Se graficó el conjunto de entrenamiento en 2D utilizando las dos primeras componentes principales del PCA aplicado sobre representaciones TF-IDF. Se compararon cinco configuraciones distintas del CountVectorizer, variando el uso de *stopwords*, *n-gramas* y *puntuación*.
#
#
# #### Resultados por configuración:
#
# **1. default** (ngram_range=(1,1), sin stopwords)
# - Donald Trump aparece claramente separado del resto.
# - Joe Biden y Bernie Sanders se solapan considerablemente, aunque con cierta tendencia a agruparse por color.
# - Se observa una alta densidad general de puntos en la región superior derecha.
#
# **2. stopwords_en** (stop_words='english')
# - Donald Trump permanece claramente separado del resto, igual que en la configuración default.
# - Al eliminar las palabras vacías, los discursos de Joe Biden y Bernie Sanders muestran **mayor dispersión**, especialmente Sanders, que se solapa más con el resto.
# - Esta configuración **no mejora la compacidad ni la separación entre Biden y Sanders**, aunque acentúa diferencias al eliminar términos genéricos.
#
# **3. ngram_1_2** (ngram_range=(1,2), sin stopwords)
# - Donald Trump sigue estando bien separado del resto, como en la configuración default.
# - Joe Biden se mantiene agrupado, sin mejoras claras en su estructura.
# - Bernie Sanders permanece disperso y con superposición respecto a Biden.
# - La incorporación de bigramas no mejora significativamente la separación visual entre oradores.
#
# **4. stop_en_ngram_1_2** (stop_words='english', ngram_range=(1,2))
# - Donald Trump mantiene una separación clara respecto a los demás, ahora con límites más definidos.
# - Joe Biden se agrupa de forma compacta en una región bien diferenciada.
# - Bernie Sanders aún se solapa parcialmente con Biden, pero con menos dispersión que en default.
# - Esta configuración produce una estructura más clara y ordenada, siendo la que mejor refleja la separación entre estilos discursivos.
#
# **5. keep_punctuation** (incluye signos de puntuación)
# - La distribución general es muy similar a la de default.
# - Donald Trump se mantiene claramente separado.
# - Joe Biden y Bernie Sanders no muestran mejoras en separación, y Sanders incluso aparece más disperso.
# - Incluir signos de puntuación **no aporta diferenciación** y puede introducir ruido innecesario.
#
# ### Conclusión
#
# - La combinación de **stopwords en inglés** y **bigrama** genera la mejor separación de clases.
# - **Incluir puntuación no mejora** la representación: puede descartarse.
# - Aunque PCA reduce la dimensionalidad, se logra visualizar patrones consistentes entre oradores.

# %% [markdown]
# ## Parte 2: Entrenamiento y Evaluación de Modelos

# %%
# 1: Entrene el modelo Multinomial Naive Bayes, luego utilícelo para predecir sobre el conjunto de test, y reporte el valor de accuracy y la matriz de confusión.

# %%
# Definir el pipeline completo
text_clf = Pipeline([
    ('vect', CountVectorizer()),
    ('tfidf', TfidfTransformer()),
    ('clf', MultinomialNB())
])

# Entrenar el modelo sobre el conjunto de desarrollo
text_clf.fit(X_dev, y_dev)

# Predecir sobre el conjunto de test
y_pred = text_clf.predict(X_test)

# Calcular y mostrar las métricas
accuracy = metrics.accuracy_score(y_test, y_pred)
precision = metrics.precision_score(y_test, y_pred, average='weighted')
recall = metrics.recall_score(y_test, y_pred, average='weighted')
f1 = metrics.f1_score(y_test, y_pred, average='weighted')

print(f"Accuracy  : {accuracy:.4f}")
print(f"Precision : {precision:.4f}")
print(f"Recall    : {recall:.4f}")
print(f"F1-Score  : {f1:.4f}")
# Out:
# Accuracy  : 0.5439
# Precision : 0.2958
# Recall    : 0.5439
# F1-Score  : 0.3832
# c:\Users\karin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# Mostrar la matriz de confusión
conf_matrix = metrics.confusion_matrix(y_test, y_pred)
print("Matriz de confusión:")
print(conf_matrix)
# Out:
# Matriz de confusión:
# [[ 0  0  8]
#  [ 0  0 18]
#  [ 0  0 31]]

# %%
# Reporte el valor de precision y recall para cada candidato. 
print(classification_report(y_test, y_pred, digits=3))
# Out:
#                 precision    recall  f1-score   support
#
# bernie sanders      0.000     0.000     0.000         8
#   donald trump      0.000     0.000     0.000        18
#      joe biden      0.544     1.000     0.705        31
#
#       accuracy                          0.544        57
#      macro avg      0.181     0.333     0.235        57
#   weighted avg      0.296     0.544     0.383        57
# c:\Users\karin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\karin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\karin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# Calcular matriz de confusión Sugerencia: utilice el método from_predictions de ConfusionMatrixDisplay para realizar la matriz.


# Mostrar matriz de confusión con etiquetas
ConfusionMatrixDisplay.from_predictions(
    y_test, 
    y_pred, 
    display_labels=text_clf.classes_,  # Usa las etiquetas conocidas por el clasificador
    cmap='Blues',
    normalize=None  # También podés usar 'true' o 'pred' si querés normalizar
)

plt.title("Matriz de confusión - Multinomial Naive Bayes")
plt.show()

# %% [markdown]
# ### Evaluación del modelo sin corrección de desbalanceo
#
# El modelo Multinomial Naive Bayes entrenado sobre el conjunto original presenta un **desempeño muy pobre** en la clasificación de discursos, especialmente para clases minoritarias.
#
# #### Principales observaciones:
#
# - El modelo **predice exclusivamente la clase "Joe Biden"**, ignorando completamente las otras dos clases.
#
# - Esto se refleja en:
#
#   - Recall = 1.0 para Biden, pero 0.0 para Trump y Sanders.
#
#   - Precision = 0.0 para Trump y Sanders, lo que indica **ninguna predicción correcta** para esas clases.
#
#   - F1-score = 0.0 para ambas clases minoritarias.
#
# #### Causa probable:
#
# Este comportamiento es resultado directo del **desbalance de clases** en el conjunto de entrenamiento, donde:
# - Biden tiene 70 ejemplos
# - Trump tiene 42
# - Sanders solo 19
#
# #### Implicación:
#
# El modelo aprende a **maximizar la accuracy prediciendo siempre la clase mayoritaria**, pero no generaliza. Esto confirma que es necesario aplicar alguna estrategia para corregir el desbalance antes de continuar con el entrenamiento.

# %%
# 2: Implemente una búsqueda de hiperparámetros usando GridSearchCV.

# %%
# Genere una visualización que permita comparar las métricas (e.g: accuracy) de los distintos modelos entrenados, viendo el valor promedio y variabilidad de las mismas en todos los splits (e.g: en un gráfico de violín).

# Definimos la grilla de hiperparámetros a buscar
parameters = {
    # Como CountVectorizer tokeniza el texto:
    'vect__ngram_range': [(1, 1), (1, 2)],      # (1, 1): usa solo unigramas (palabras individuales). // (1, 2): usa unigramas y bigramas (secuencias de 2 palabras).  // Más bigramas : más contexto, pero también más dimensiones.
    'tfidf__use_idf': (True, False),            # True: aplica TF-IDF normal (penaliza palabras comunes en todo el corpus).  // False: solo usa TF (frecuencia dentro del documento), sin penalizar palabras comunes.
    # Parámetro de suavizado de Laplace en MultinomialNB.
    'clf__alpha': (1.0, 0.1, 0.01)              # alpha más bajo --> menos suavizado --> puede sobreajustar.  // alpha más alto --> más suavizado --> más general.
}

# Ejecutamos la búsqueda
gs_clf = GridSearchCV(text_clf, parameters, cv=5, n_jobs=-1, scoring='f1_macro') # n_jobs=-1: usa todos los núcleos disponibles del procesador --> máxima paralelización
gs_clf = gs_clf.fit(X_dev, y_dev)

# %%
# Mejor combinación encontrada
print("Mejores hiperparámetros encontrados:")
for param_name in sorted(parameters.keys()):
    print(f"{param_name}: {gs_clf.best_params_[param_name]}")

# Accuracy con esos parámetros
print(f"\nMejor score (cross-validation): {gs_clf.best_score_:.4f}")
# Out:
# Mejores hiperparámetros encontrados:
# clf__alpha: 0.01
# tfidf__use_idf: True
# vect__ngram_range: (1, 1)
#
# Mejor score (cross-validation): 0.9139

# %% [markdown]
# ### Optimización de Hiperparámetros para maximizar F1-score
#
# #### Mejores hiperparámetros encontrados:
# - vect__ngram_range: (1, 1) --> Solo unigramas
# - tfidf__use_idf: True --> Se aplicó penalización por frecuencia de documento
# - clf__alpha: 0.01 --> Menor suavizado (modelo más específico)
#
# #### Score promedio en validación cruzada (cv=5):
# - **F1-Score promedio:** 0.9139

# %%
# Genere una visualización que permita comparar las métricas (e.g: accuracy) 
# de los distintos modelos entrenados, viendo el valor promedio y variabilidad de las mismas en todos los splits (e.g: en un gráfico de violín). 

# Accedemos a los resultados de GridSearchCV
cv_results = pd.DataFrame(gs_clf.cv_results_)

# Crear identificador corto tipo "split 1", "split 2", ...
cv_results['split_id'] = [f"split {i+1}" for i in range(len(cv_results))]
cv_results['params_str'] = cv_results['params'].apply(str)

# Expandimos los F1-scores de los 5 folds por combinación
rows = []
for idx, row in cv_results.iterrows():
    for i in range(5):  # para split0 a split4
        score = row[f'split{i}_test_score']
        split_id = row['split_id']
        rows.append({'split_id': split_id, 'f1_score': score})  

scores_df = pd.DataFrame(rows)

# Definir orden explícito para los splits
split_order = [f"split {i}" for i in range(1, 13)]
scores_df['split_id'] = pd.Categorical(scores_df['split_id'], categories=split_order, ordered=True)
cv_results['split_id'] = pd.Categorical(cv_results['split_id'], categories=split_order, ordered=True)

# Valor de F1-score final (mejor promedio)
final_f1 = gs_clf.best_score_
best_split = cv_results.loc[cv_results['mean_test_score'].idxmax(), 'split_id']
best_split_idx = split_order.index(best_split)

# Calcular el promedio de F1 por split
mean_scores = scores_df.groupby('split_id')['f1_score'].mean().reindex(split_order)

# Gráfico + tabla en subplots
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(16, 12), gridspec_kw={'height_ratios': [3, 1]})
fig.subplots_adjust(hspace=0.4)

# Violinplot de F1-score
sns.violinplot(data=scores_df, x='split_id', y='f1_score', inner='point', order=split_order, ax=ax1)

# Agregar puntos promedio
x_positions = np.arange(len(split_order))
y_means = mean_scores.values
ax1.scatter(x=x_positions, y=y_means, color='red', s=50, label='Promedio por split', zorder=5)

# Estrella en el mejor split
ax1.scatter(x=best_split_idx, y=mean_scores.iloc[best_split_idx],
            color='red', s=120, marker='*', label='Mejor split', zorder=6)

# Línea horizontal con el mejor F1-score
ax1.axhline(final_f1, color='red', linestyle='--', label=f'F1-score final ({final_f1:.3f})')

# Títulos
ax1.set_title("Distribución de F1-score por combinación de hiperparámetros (5-fold CV)", fontsize=18, pad=20)
ax1.set_xlabel("Combinación (split)", fontsize=12)
ax1.set_ylabel("F1-score (macro)", fontsize=12)
ax1.legend()

# Tabla visual
ax2.axis('off')
tabla_data = [[row['split_id'], row['params_str']] for _, row in cv_results.iterrows()]
tabla_plot = ax2.table(cellText=tabla_data,
                       colLabels=["Split", "Combinación de hiperparámetros"],
                       loc='center',
                       cellLoc='center',
                       colLoc='center')

tabla_plot.auto_set_font_size(False)
tabla_plot.set_fontsize(10)
tabla_plot.scale(1, 1.5)

for key, cell in tabla_plot.get_celld().items():
    if key[0] == 0:
        cell.set_text_props(weight='bold')

plt.show()
# Out:
# C:\Users\karin\AppData\Local\Temp\ipykernel_24152\942698398.py:32: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_scores = scores_df.groupby('split_id')['f1_score'].mean().reindex(split_order)
# c:\Users\karin\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
# Mostrar los datos del gráfico
data = cv_results[['split0_test_score', 'split1_test_score', 'split2_test_score',
       'split3_test_score', 'split4_test_score', 'mean_test_score','split_id', 'params_str']]

data
# Out:
#     split0_test_score  split1_test_score  split2_test_score  \
# 0            0.227642           0.233333           0.233333
# 1            0.227642           0.233333           0.233333
# 2            0.227642           0.233333           0.233333
# 3            0.227642           0.233333           0.233333
# 4            0.497354           0.541176           0.560224
# 5            0.533333           0.574495           0.593939
# 6            0.227642           0.233333           0.233333
# 7            0.227642           0.233333           0.233333
# 8            0.968898           0.891980           0.940887
# 9            0.837023           0.861814           0.940887
# 10           0.596554           0.605392           0.593939
# 11           0.533333           0.605392           0.593939
#
#     split3_test_score  split4_test_score  mean_test_score  split_id  \
# 0            0.233333           0.233333         0.232195   split 1
# 1            0.233333           0.233333         0.232195   split 2
# 2            0.233333           0.233333         0.232195   split 3
# 3            0.233333           0.233333         0.232195   split 4
# 4            0.560224           0.434070         0.518610   split 5
# 5            0.625000           0.481481         0.561650   split 6
# 6            0.233333           0.233333         0.232195   split 7
# 7            0.233333           0.233333         0.232195   split 8
# 8            1.000000           0.767742         0.913901   split 9
# 9            0.940887           0.625000         0.841122  split 10
# 10           0.625000           0.560224         0.596222  split 11
# 11           0.625000           0.481481         0.567829  split 12
#
#                                            params_str
# 0   {'clf__alpha': 1.0, 'tfidf__use_idf': True, 'v...
# 1   {'clf__alpha': 1.0, 'tfidf__use_idf': True, 'v...
# 2   {'clf__alpha': 1.0, 'tfidf__use_idf': False, '...
# 3   {'clf__alpha': 1.0, 'tfidf__use_idf': False, '...
# 4   {'clf__alpha': 0.1, 'tfidf__use_idf': True, 'v...
# 5   {'clf__alpha': 0.1, 'tfidf__use_idf': True, 'v...
# 6   {'clf__alpha': 0.1, 'tfidf__use_idf': False, '...
# 7   {'clf__alpha': 0.1, 'tfidf__use_idf': False, '...
# 8   {'clf__alpha': 0.01, 'tfidf__use_idf': True, '...
# 9   {'clf__alpha': 0.01, 'tfidf__use_idf': True, '...
# 10  {'clf__alpha': 0.01, 'tfidf__use_idf': False, ...
# 11  {'clf__alpha': 0.01, 'tfidf__use_idf': False, ...

# %%
# 3: Elija el mejor modelo (mejores parámetros) y vuelva a entrenar sobre todo el conjunto de entrenamiento disponible (sin quitar datos para validación). 

best_params = gs_clf.best_params_

# Nuevo pipeline con los mejores hiperparámetros
final_clf = Pipeline([
    ('vect', CountVectorizer(ngram_range=best_params['vect__ngram_range'])),
    ('tfidf', TfidfTransformer(use_idf=best_params['tfidf__use_idf'])),
    ('clf', MultinomialNB(alpha=best_params['clf__alpha']))
])

# Entrenamos sobre TODO el conjunto de entrenamiento
final_clf.fit(X_dev, y_dev)
# Out:
# Pipeline(steps=[('vect', CountVectorizer()), ('tfidf', TfidfTransformer()),
#                 ('clf', MultinomialNB(alpha=0.01))])

# %%
# Reporte el valor final de las métricas y la matriz de confusión.

# Predicción sobre test
y_pred_final = final_clf.predict(X_test)

# Reporte de métricas
print("Reporte de clasificación en test:")
print(classification_report(y_test, y_pred_final, digits=3))

# Matriz de confusión
ConfusionMatrixDisplay.from_predictions(y_test, y_pred_final, cmap='Blues')
plt.title("Matriz de confusión - Modelo final optimizado")
plt.show()
# Out:
# Reporte de clasificación en test:
#                 precision    recall  f1-score   support
#
# bernie sanders      1.000     0.750     0.857         8
#   donald trump      1.000     1.000     1.000        18
#      joe biden      0.939     1.000     0.969        31
#
#       accuracy                          0.965        57
#      macro avg      0.980     0.917     0.942        57
#   weighted avg      0.967     0.965     0.963        57

# %%
acc = accuracy_score(y_test, y_pred_final)
f1 = f1_score(y_test, y_pred_final, average='macro')  

print(f"Accuracy : {acc:.4f}")
print(f"F1-Score : {f1:.4f}")
# Out:
# Accuracy : 0.9649
# F1-Score : 0.9420

# %% [markdown]
# ### Evaluación final del modelo optimizado
#
# Tras realizar la búsqueda de hiperparámetros con GridSearchCV utilizando **f1_macro como métrica de optimización**, se entrenó el modelo final con los mejores parámetros encontrados sobre **todo el conjunto de entrenamiento (X_dev)**, y se evaluó su desempeño sobre el **conjunto de test (X_test)**.
#
# #### Reporte de clasificación:
#
# - **Accuracy total:** 96.5%
# - **F1-score macro promedio:** 0.942
# - **F1-score ponderado (weighted):** 0.963
#
# #### 🔍 Observaciones:
#
# - El modelo **clasificó correctamente todos los discursos de Donald Trump y Joe Biden**, alcanzando **F1-score de 1.000** y **0.969**, respectivamente.
# - Para *Bernie Sanders*, el modelo alcanzó un **F1-score de 0.857**, con un **recall de 0.75**, lo que indica que se detectaron 6 de los 8 discursos correctamente.
# - La clase de Sanders es la menos representada en el test (solo 8 ejemplos), lo cual explica una mayor sensibilidad a errores.
# - La mejora respecto al modelo base (sin optimización) es clara: **el macro F1-score pasó de un valor considerablemente más bajo (por debajo de 0.60) a 0.942**, con una mejora notable en la equidad entre clases.
#
# #### Conclusión:
#
# La **optimización de hiperparámetros** (ajuste del parámetro de suavizado alpha, uso de bigramas y decisión de aplicar o no TF-IDF) tuvo un **impacto determinante en la calidad del modelo**.
# Optimizar en función de **f1_macro permitió balancear el desempeño entre clases**, especialmente en presencia de clases desbalanceadas, corrigiendo el sesgo del modelo base hacia la clase mayoritaria.

# %%
# 4: Evalúe con validación cruzada al menos un modelo más (dentro de scikit-learn) aparte de Multinomial Naive Bayes para clasificar el texto utilizando las mismas features de texto.

# Definimos el pipeline con un clasificador SVM lineal
svm_pipeline = Pipeline([
    ('vect', CountVectorizer()),
    ('tfidf', TfidfTransformer()),
    ('clf', SGDClassifier(random_state=42, max_iter=1000, tol=1e-3))
])

# Definimos la grilla de hiperparámetros a buscar
svm_params = {
    # Como CountVectorizer tokeniza el texto:
    'vect__ngram_range': [(1, 1), (1, 2)],     
    # (1, 1): usa solo unigramas (palabras individuales).
    # (1, 2): usa unigramas y bigramas (secuencias de 2 palabras).
    # Más bigramas → más contexto semántico, pero también más features.

    'tfidf__use_idf': [True, False],           
    # True: aplica TF-IDF clásico (penaliza palabras comunes en todo el corpus).
    # False: solo usa TF (frecuencia dentro del documento), sin penalización global.

    'clf__alpha': [1e-2, 1e-3, 1e-4],          
    # Controla la regularización del modelo (parecido a 1/C en SVM clásico).
    # Valores más bajos → menos regularización → posible sobreajuste.
    # Valores más altos → más regularización → generaliza más, menos sobreajuste.

    'clf__penalty': ['l2', 'l1'],              
    # Tipo de regularización:
    # 'l2': penaliza pesos grandes, tiende a mantener más features.
    # 'l1': induce dispersión (sparse), elimina features menos relevantes.

    'clf__loss': ['hinge', 'log_loss']         
    # Función de pérdida:
    # 'hinge' → SVM clásico.
    # 'log_loss' → regresión logística (también útil para clasificación binaria/multiclase).
}

# Ejecutamos la búsqueda con validación cruzada
gs_svm = GridSearchCV(svm_pipeline, svm_params, cv=5, n_jobs=-1, scoring='f1_macro')
gs_svm.fit(X_dev, y_dev)

# Mostramos los mejores parámetros encontrados
print("Mejores hiperparámetros encontrados:")
for param_name in sorted(svm_params.keys()):
    print(f"{param_name}: {gs_svm.best_params_[param_name]}")

print(f"\nMejor score (cross-validation): {gs_svm.best_score_:.4f}")
# Out:
# Mejores hiperparámetros encontrados:
# clf__alpha: 0.001
# clf__loss: hinge
# clf__penalty: l1
# tfidf__use_idf: True
# vect__ngram_range: (1, 2)
#
# Mejor score (cross-validation): 0.9742

# %%
# Entrenar el mejor modelo sobre todo el conjunto de desarrollo
best_svm = gs_svm.best_estimator_
best_svm.fit(X_dev, y_dev)
# Out:
# Pipeline(steps=[('vect', CountVectorizer(ngram_range=(1, 2))),
#                 ('tfidf', TfidfTransformer()),
#                 ('clf',
#                  SGDClassifier(alpha=0.001, penalty='l1', random_state=42))])

# %%
# Predicciones en test
y_pred_svm = best_svm.predict(X_test)

# Accuracy y F1-score
acc_svm = accuracy_score(y_test, y_pred_svm)
f1_svm = f1_score(y_test, y_pred_svm, average='macro')  

print(f"Accuracy en test (SVM optimizado): {acc_svm:.4f}")
print(f"F1-Score en test (SVM optimizado): {f1_svm:.4f}")

# Reporte de clasificación
print("\nReporte de clasificación (SVM optimizado):")
print(classification_report(y_test, y_pred_svm, digits=3))

# Matriz de confusión
ConfusionMatrixDisplay.from_predictions(y_test, y_pred_svm, cmap='Blues')
plt.title("Matriz de confusión - Modelo SVM optimizado")
plt.show()
# Out:
# Accuracy en test (SVM optimizado): 0.9649
# F1-Score en test (SVM optimizado): 0.9540
#
# Reporte de clasificación (SVM optimizado):
#                 precision    recall  f1-score   support
#
# bernie sanders      1.000     0.875     0.933         8
#   donald trump      0.944     0.944     0.944        18
#      joe biden      0.969     1.000     0.984        31
#
#       accuracy                          0.965        57
#      macro avg      0.971     0.940     0.954        57
#   weighted avg      0.965     0.965     0.964        57

# %% [markdown]
# ### Evaluación del modelo alternativo: SVM optimizado (SGDClassifier)
#
# Se evaluó un segundo modelo utilizando un clasificador lineal basado en **SVM (via SGDClassifier)**, optimizado mediante GridSearchCV con validación cruzada de 5 folds. Se mantuvieron las mismas transformaciones de texto (CountVectorizer + TF-IDF) y se utilizó como métrica de optimización el **f1_macro**.
#
# El modelo final fue entrenado con los mejores hiperparámetros sobre **todo el conjunto de entrenamiento (X_dev)** y evaluado en el **conjunto de test (X_test)**.
#
# #### Reporte de clasificación:
#
# - **Accuracy en test:** 96.5%
# - **F1-score macro promedio:** 0.954
# - **F1-score ponderado (weighted):** 0.964
#
# #### Observaciones:
#
# - El modelo obtuvo un **F1-score de 0.984** para *Joe Biden*, **0.944** para *Donald Trump* y **0.933** para *Bernie Sanders*.
# - La clase *Bernie Sanders*, con solo 8 ejemplos, alcanzó un **recall de 0.875**, mejorando respecto al modelo Naive Bayes.
# - El macro F1-score es **ligeramente superior** al del modelo anterior (0.954 vs. 0.942), indicando una mejora en el equilibrio entre clases.
#
# #### Conclusión:
#
# El modelo SVM optimizado logra un desempeño **muy competitivo**, con resultados sólidos en todas las clases. Su rendimiento, particularmente en la clase minoritaria (*Bernie Sanders*), mejora respecto al modelo Naive Bayes, mostrando mayor capacidad de generalización con un leve aumento en el F1-score macro.
# Esto confirma que la elección del modelo y la métrica de optimización (f1_macro) fueron adecuadas para este problema multiclase con clases desbalanceadas.

# %%
# 5: Evalúe el problema cambiando al menos un candidato. En particular, observe el (des)balance de datos y los problemas que pueda generar, así como cualquier indicio que pueda ver en el mapeo previo con PCA.

# %% [markdown]
# ### Preparación del Dataframe cambiando a Bernie Sanders por Mike Pence

# %%
# Paso 1: seleccionar columnas
df_reducido2 = df_speeches_sin_encabezados[['text1', 'joe biden', 'donald trump', 'mike pence']].copy()

# Paso 2: melt
df_melted2 = df_reducido2.melt(
    id_vars='text1',
    value_vars=['joe biden', 'donald trump', 'mike pence'],
    var_name='target',
    value_name='text_orador'
)

# Paso 3: eliminar vacíos/nulos
df_melted2 = df_melted2[df_melted2['text_orador'].notna() & (df_melted2['text_orador'].str.strip() != '')].reset_index(drop=True)

# Paso 4: aplicar limpieza
df_melted2['clean_text'] = clean_text(df_melted2, 'text_orador')

# %%
## Verificamos

# Función auxiliar: cuenta celdas con texto no vacío
def contar_textos_no_vacios(df, columnas):
    return sum((df[col].str.strip() != '').sum() for col in columnas)

# Columnas que nos interesan
columnas_oradores = ['joe biden', 'donald trump', 'mike pence']

# Conteo real de celdas con texto en el DataFrame original
conteo_original = contar_textos_no_vacios(df_speeches_sin_encabezados, columnas_oradores)

# Conteo de filas en el nuevo DataFrame ya "derretido"
conteo_melted2 = len(df_melted2)

print(f"Cantidad de celdas con texto en columnas originales: {conteo_original}")
print(f"Cantidad de filas en el nuevo DataFrame: {conteo_melted2}")

if conteo_original == conteo_melted2:
    print("✅ Coinciden: no se perdió información.")
else:
    print("⚠️ No coinciden: hay pérdida o exceso de datos.")
# Out:
# Cantidad de celdas con texto en columnas originales: 184
# Cantidad de filas en el nuevo DataFrame: 184
# ✅ Coinciden: no se perdió información.

# %%
# Crear un Dataframe que solo contiene las columnas para Clasificación
df_clf2 = df_melted2[['clean_text', 'target']]

# %% [markdown]
# ## Evaluación del problema cambiando a Bernie Sanders por Mike Pence

# %%
# 1: Separar 30% del conjunto para test. Al resto lo llamamos "dev" (desarrollo).

# Variables originales
X2 = df_clf2['clean_text']
y2 = df_clf2['target']

# División estratificada para mantener proporciones por clase
X2_dev, X2_test, y2_dev, y2_test = train_test_split(
    X2, y2, test_size=0.3, random_state=42, stratify=y2
)

# Mostrar tamaños de los conjuntos
print(f"Tamaños de los conjuntos: dev = {X2_dev.shape}, test = {X2_test.shape}")
print(f"Tamaños de los conjuntos: dev = {y2_dev.shape}, test = {y2_test.shape}")
# Out:
# Tamaños de los conjuntos: dev = (128,), test = (56,)
# Tamaños de los conjuntos: dev = (128,), test = (56,)

# %%
# 2: Visualización de la proporción de cada candidato por conjunto

# Conteo de discursos por orador en cada conjunto
print("Distribución en el conjunto de desarrollo (dev):")
print(y2_dev.value_counts())

print("\nDistribución en el conjunto de test:")
print(y2_test.value_counts())
# Out:
# Distribución en el conjunto de desarrollo (dev):
# target
# joe biden       70
# donald trump    42
# mike pence      16
# Name: count, dtype: int64
#
# Distribución en el conjunto de test:
# target
# joe biden       31
# donald trump    18
# mike pence       7
# Name: count, dtype: int64

# %%
# 3: Transforme el texto del conjunto de entrenamiento a la representación numérica (features) de conteo de palabras o bag of words.

# Crear el vectorizador y ajustarlo al conjunto de desarrollo
count_vect = CountVectorizer()

# Aplicar fit_transform para construir el vocabulario y transformar el texto
X2_dev_counts = count_vect.fit_transform(X2_dev)

# Mostrar forma de la matriz resultante
print("Shape de la matriz de conteo (Bag of Words):", X2_dev_counts.shape)

# 4: Obtenga la representación numérica Term Frequency - Inverse Document Frequency.

# Crear el transformador TF-IDF
tfidf2_transformer = TfidfTransformer()

# Ajustar al conjunto de desarrollo y transformar
X2_dev_tfidf = tfidf2_transformer.fit_transform(X2_dev_counts)

# Mostrar la shape de la matriz resultante
print("Shape de la matriz TF-IDF:", X2_dev_tfidf.shape)
# Out:
# Shape de la matriz de conteo (Bag of Words): (128, 12737)
# Shape de la matriz TF-IDF: (128, 12737)

# %%
# 5 :Muestre en un mapa el conjunto de entrenamiento, utilizando las dos primeras componentes PCA sobre los vectores de tf-idf.

# Convertimos la matriz dispersa a array denso
X2_dense = X2_dev_tfidf.toarray()

# Aplicamos PCA para reducir a 2 dimensiones
pca2 = PCA(n_components=2)
X2_pca = pca2.fit_transform(X2_dense)

# Graficamos en 2D con colores por orador
plt.figure(figsize=(8, 6))

for label in y2_dev.unique():
    idx = y2_dev == label
    plt.scatter(X2_pca[idx, 0], X2_pca[idx, 1], label=label, alpha=0.7)

plt.title("Mapa del conjunto de entrenamiento por orador con dos componentes del PCA")
plt.xlabel("Componente principal 1")
plt.ylabel("Componente principal 2")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Análisis visual con PCA tras reemplazar a Bernie Sanders por Mike Pence
#
# Se aplicó Análisis de Componentes Principales (PCA) sobre los vectores TF-IDF del conjunto de entrenamiento con los oradores: **Joe Biden**, **Donald Trump** y **Mike Pence**.
#
# #### Observaciones:
#
# - **Donald Trump** (naranja) forma un grupo bien definido en la parte superior derecha del gráfico, lo cual indica un vocabulario distintivo que lo separa de los demás en las dos primeras componentes principales.
#
# - **Joe Biden** (azul) aparece también agrupado, aunque con algo más de dispersión, especialmente en la parte inferior derecha. Esto sugiere un estilo consistente, pero con algo más de variabilidad.
#
# - **Mike Pence** (verde) aparece en el extremo inferior derecho, en una zona cercana a Biden. Esto puede indicar:
#
#   - Que Pence comparte vocabulario o estructura de discurso con Biden (o al menos menos diferenciación que Trump).
#   - Que la poca cantidad de discursos disponibles de Pence no alcanzó para definir una región clara en el espacio PCA.
#
# #### Conclusión:
#
# El mapeo visual apoya los resultados del modelo:
# - Pence es **razonablemente distinguible**, pero no tan claramente separado como Trump.
# - Se visualiza una **ligera superposición léxica** entre Pence y Biden, que puede dificultar su separación cuando hay pocos datos.
#
# > Este análisis ilustra cómo la **cantidad de ejemplos** y la **similitud lingüística** entre oradores impactan tanto en el modelo como en la representación visual reducida mediante PCA.

# %%
# 4: Evalúe con validación cruzada al menos un modelo más (dentro de scikit-learn) aparte de Multinomial Naive Bayes para clasificar el texto utilizando las mismas features de texto.

# Definimos el pipeline con un clasificador SVM lineal
svm_pipeline2 = Pipeline([
    ('vect', CountVectorizer()),
    ('tfidf', TfidfTransformer()),
    ('clf', SGDClassifier(random_state=42, max_iter=1000, tol=1e-3))
])

# Definimos la grilla de hiperparámetros a buscar
svm_params2 = {
    # Como CountVectorizer tokeniza el texto:
    'vect__ngram_range': [(1, 1), (1, 2)],     
    # (1, 1): usa solo unigramas (palabras individuales).
    # (1, 2): usa unigramas y bigramas (secuencias de 2 palabras).
    # Más bigramas → más contexto semántico, pero también más features.

    'tfidf__use_idf': [True, False],           
    # True: aplica TF-IDF clásico (penaliza palabras comunes en todo el corpus).
    # False: solo usa TF (frecuencia dentro del documento), sin penalización global.

    'clf__alpha': [1e-2, 1e-3, 1e-4],          
    # Controla la regularización del modelo (parecido a 1/C en SVM clásico).
    # Valores más bajos → menos regularización → posible sobreajuste.
    # Valores más altos → más regularización → generaliza más, menos sobreajuste.

    'clf__penalty': ['l2', 'l1'],              
    # Tipo de regularización:
    # 'l2': penaliza pesos grandes, tiende a mantener más features.
    # 'l1': induce dispersión (sparse), elimina features menos relevantes.

    'clf__loss': ['hinge', 'log_loss']         
    # Función de pérdida:
    # 'hinge' → SVM clásico.
    # 'log_loss' → regresión logística (también útil para clasificación binaria/multiclase).
}

# Ejecutamos la búsqueda con validación cruzada
gs_svm2 = GridSearchCV(svm_pipeline2, svm_params2, cv=5, n_jobs=-1, scoring='f1_macro')
gs_svm2.fit(X2_dev, y2_dev)

# Mostramos los mejores parámetros encontrados
print("Mejores hiperparámetros encontrados:")
for param_name in sorted(svm_params2.keys()):
    print(f"{param_name}: {gs_svm2.best_params_[param_name]}")

print(f"\nMejor score (cross-validation): {gs_svm2.best_score_:.4f}")
# Out:
# Mejores hiperparámetros encontrados:
# clf__alpha: 0.0001
# clf__loss: log_loss
# clf__penalty: l2
# tfidf__use_idf: False
# vect__ngram_range: (1, 1)
#
# Mejor score (cross-validation): 0.9940

# %%
# Entrenar el mejor modelo sobre todo el conjunto de desarrollo
best_svm2 = gs_svm2.best_estimator_
best_svm2.fit(X2_dev, y2_dev)
# Out:
# Pipeline(steps=[('vect', CountVectorizer()),
#                 ('tfidf', TfidfTransformer(use_idf=False)),
#                 ('clf', SGDClassifier(loss='log_loss', random_state=42))])

# %%
# Predicciones en test para la segunda variante (cambiando un candidato)
y2_pred_svm = best_svm2.predict(X2_test)

# Accuracy y F1-score macro
acc_svm2 = accuracy_score(y2_test, y2_pred_svm)
f1_svm2 = f1_score(y2_test, y2_pred_svm, average='macro')

print(f"Accuracy en test (SVM optimizado): {acc_svm2:.4f}")
print(f"F1-Score en test (SVM optimizado): {f1_svm2:.4f}")

# Reporte de clasificación detallado
print("\nReporte de clasificación (SVM optimizado):")
print(classification_report(y2_test, y2_pred_svm, digits=3))

# Matriz de confusión
ConfusionMatrixDisplay.from_predictions(y2_test, y2_pred_svm, cmap='Blues')
plt.title("Matriz de confusión - Modelo SVM optimizado (candidato cambiado)")
plt.show()
# Out:
# Accuracy en test (SVM optimizado): 0.9107
# F1-Score en test (SVM optimizado): 0.8778
#
# Reporte de clasificación (SVM optimizado):
#               precision    recall  f1-score   support
#
# donald trump      1.000     0.889     0.941        18
#    joe biden      0.882     0.968     0.923        31
#   mike pence      0.833     0.714     0.769         7
#
#     accuracy                          0.911        56
#    macro avg      0.905     0.857     0.878        56
# weighted avg      0.914     0.911     0.910        56

# %%
# Convertimos los resultados a DataFrame
cv_results_df2 = pd.DataFrame(gs_svm2.cv_results_)

data2 = cv_results_df2[[
    'split0_test_score', 'split1_test_score', 'split2_test_score',
    'split3_test_score', 'split4_test_score', 'mean_test_score', 'params'
]]

# Mostramos
#data2

# %% [markdown]
# ### Conclusión
#
# El modelo SVM optimizado alcanzó un **accuracy del 91.1%** y un **F1-score macro de 0.878** en el conjunto de test, clasificando discursos de **Joe Biden**, **Donald Trump** y **Mike Pence**.
# El rendimiento fue alto en general, pero no completamente simétrico entre clases.
#
# #### Rendimiento por clase:
#
# - **Donald Trump**: precision = 1.00, recall = 0.89, F1 = 0.941
#   → El modelo predice muy bien a Trump, aunque **2 de sus discursos fueron clasificados como Biden** (falsos negativos).
#
# - **Joe Biden**: precision = 0.88, recall = 0.97, F1 = 0.923
#   → Fue correctamente clasificado en 30 de 31 casos. Sin embargo, **1 discurso fue confundido con Pence**, lo que afecta su precisión.
#
# - **Mike Pence**: precision = 0.83, recall = 0.71, F1 = 0.769
#   → Es la clase más débil: **solo 5 de 7 discursos fueron correctamente clasificados**. Los 2 errores fueron predicciones como Biden, lo que indica dificultades del modelo para separarlos.
#
# #### Relación con la matriz de confusión:
#
# |                | Pred. Trump | Pred. Biden | Pred. Pence |
# |----------------|-------------|-------------|-------------|
# | **True Trump** |     16      |      2      |      0      |
# | **True Biden** |      0      |     30      |      1      |
# | **True Pence** |      0      |      2      |      5      |
#
# - La **mayor fuente de error está en las confusiones cruzadas con Joe Biden**: Biden es confundido con Pence, Pence con Biden, y Trump con Biden.
# - No se producen errores directos entre Trump y Pence.
#
# #### Relación con el análisis PCA:
#
# - En el mapa PCA, **Trump aparece bien separado**, lo que concuerda con su alta precisión.
# - **Biden se ubica en una zona intermedia**, solapándose con ambos candidatos, lo que explica su rol como punto de confusión.
# - **Pence se solapa con Biden**, sin ser confundido con Trump, lo que coincide con los errores observados.
#
# #### Conclusión general:
#
# - Este modelo SVM optimizado, si bien sólido, **obtuvo un desempeño inferior al modelo anterior con Bernie Sanders** (f1_macro = 0.8778 vs. 0.9540), lo que evidencia el impacto del cambio de clase minoritaria.
# - **La escasa representación de Mike Pence y su similitud léxica con Biden** afectaron tanto su recall como su F1-score.
# - Las confusiones que surgen están alineadas con la **estructura semántica del corpus observada en PCA**, y muestran cómo incluso modelos bien ajustados pueden fallar si hay **desequilibrio entre clases** o **solapamiento semántico**.
# - El uso de métricas como f1_macro, junto con análisis visuales, permite diagnosticar estas limitaciones de forma clara.
#
# > Este análisis refuerza la importancia de considerar no solo la cantidad de ejemplos por clase, sino también su distancia semántica, al entrenar y evaluar clasificadores de texto.

# %%
# OPCIONAL: Repetir la clasificación con los tres candidatos con más discursos, pero esta vez clasificando a nivel de párrafos y no de discursos enteros.
